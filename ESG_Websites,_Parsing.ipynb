# %% [markdown]
# # Parsing

# %%
# !pip install pypdf pymorphy2 selenium pymupdf
# !apt-get update
# !apt install chromium-chromedriver

# %%
import os, json, time, hashlib, zipfile
import warnings, gc
import requests, fitz
from itertools import islice
from io import BytesIO
import urllib3, multiprocessing
from urllib.request import urlopen
from urllib.parse import urlparse
from selenium import webdriver
from concurrent.futures import ThreadPoolExecutor, as_completed
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from pypdf import PdfReader
import pandas as pd
from IPython.display import display
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer

warnings.filterwarnings("ignore")
nltk.download('stopwords')
nltk.download('punkt')
urllib3.disable_warnings()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def download_pdf(url):
    response = requests.get(url)
    if response.status_code == 200:
        original_filename = os.path.basename(url)
        truncated_filename = truncate_filename(original_filename)
        file_path = os.path.join('/content/PDFs/', truncated_filename)
        with open(file_path, 'wb') as file:
            file.write(response.content)
        return file_path
    else:
        print(f"Failed to download PDF: {url, response.status_code}")
        return None

# %%
def truncate_filename(filename, max_length=255):
    if len(filename) > max_length:
        hash_part = hashlib.md5(filename.encode()).hexdigest()
        extension = os.path.splitext(filename)[1]
        filename = filename[:max_length - len(hash_part) - len(extension) - 1] + '-' + hash_part + extension
    return filename

# %%
def clear_string(url):
    parts = url.split(' ')
    result = []
    i = 0
    if i + 2 < len(parts) and parts[i+1] == 'и':
        result.append(parts[i])
        result.append(parts[i+2])
    else:
        result.append(parts[i])
    return result

# %%
def get_all_links(company, url):
    if ".pdf" in url.lower():
        internalLinks = []
        if "http" in url:
            filename = download_pdf(url)
            if filename is not None:
                internalLinks.append(filename)

                data = pd.DataFrame(internalLinks, columns=['urls']).drop_duplicates()
                data['company'] = company
                data = data[['company', 'urls']]

                return data

        else:
            if "/content/PDFs/" not in url:
                url = os.path.join('/content/PDFs/', url)

            internalLinks.append(url)

            data = pd.DataFrame(internalLinks, columns=['urls']).drop_duplicates()
            data['company'] = company
            data = data[['company', 'urls']]

            return data
    else:
        internalLinks = [url]
        status = 0
        try:
            response = requests.get(url=url, timeout=timeout, headers=headers, verify=False)
            status = response.status_code
        except Exception as err:
            pass

        if status == 200:
            soup = BeautifulSoup(response.content, 'lxml')
        else:
            chrome_options = webdriver.ChromeOptions()
            chrome_options.add_argument('--headless')
            chrome_options.add_argument('--no-sandbox')
            chrome_options.add_argument('--disable-gpu')
            chrome_options.add_argument('--disable-extensions')
            chrome_options.add_argument('--disable-dev-shm-usage')
            chrome_options.add_argument('--disable-blink-features=AutomationControlled')
            driver = webdriver.Chrome(options=chrome_options)

            driver.set_page_load_timeout(10)

            driver.get(url)
            soup = BeautifulSoup(driver.page_source, 'lxml')
            driver.quit()
            del driver
            gc.collect()

        for script in soup(["script", "style"]):
            script.extract()

        sublinks = [a.get('href') for a in soup.find_all('a') if a.get('href') and a.get('href').startswith('/')]
        sublinks = [link[1:] for link in sublinks]
        sublinks = [*set(sublinks)]
        sublinks = list(filter(None, sublinks))

        for link in sublinks:
            if ".pdf" not in link.lower():
                if 'www' in link:
                    new_url = os.path.join(url[:url.rfind('www')], urlparse(url).netloc, link)
                else:
                    new_url = os.path.join(url[:url.rfind('//')+2], urlparse(url).netloc, link)
                internalLinks.append(new_url)

        data = pd.DataFrame(internalLinks, columns=['urls']).drop_duplicates()
        data['company'] = company
        data = data[['company', 'urls']]

        return data

# %%
def parsing(company, url):
    if ".pdf" in url.lower():
        if "http" in url:
            filename = download_pdf(url)
            if filename is not None:
                reader = fitz.open(f"{filename}")
                text = ""
                for page in range(reader.page_count):
                    text += reader.load_page(page).get_text() + "\n"

                text = text.replace('-\n', '').lower()
                text = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', text)
                text = ''.join([i for i in text if not i.isdigit()])

                lines = (line.strip() for line in text.splitlines())
                chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
                text = '\n'.join(chunk for chunk in chunks if chunk)

                text = list(np.concatenate([sent_tokenize(i.strip()) for i in text.split('\n')]).flat)

                text_lemmatized = []
                for line in [t.split() for t in text]:
                    line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
                    text_lemmatized.append(line_lemmatized)

                data = pd.DataFrame(text_lemmatized, columns=['text']).drop_duplicates()
                data['company'] = company
                data['url'] = url
                data = data[['company', 'url', 'text']]

                return data
        else:
            if "/content/PDFs/" not in url:
                url = os.path.join('/content/PDFs/', url)

            reader = fitz.open(f"{url}")
            text = ""
            for page in range(reader.page_count):
                text += reader.load_page(page).get_text() + "\n"

            text = text.replace('-\n', '').lower()
            text = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', text)
            text = ''.join([i for i in text if not i.isdigit()])

            lines = (line.strip() for line in text.splitlines())
            chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
            text = '\n'.join(chunk for chunk in chunks if chunk)

            text = list(np.concatenate([sent_tokenize(i.strip()) for i in text.split('\n')]).flat)

            text_lemmatized = []
            for line in [t.split() for t in text]:
                line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
                text_lemmatized.append(line_lemmatized)

            data = pd.DataFrame(text_lemmatized, columns=['text']).drop_duplicates()
            data['company'] = company
            data['url'] = url
            data = data[['company', 'url', 'text']]

            return data

    else:
        status = 0
        try:
            response = requests.get(url=url, timeout=timeout, headers=headers, verify=False)
            status = response.status_code
        except Exception as err:
            pass

        if status == 200:
            soup = BeautifulSoup(response.content, 'lxml')
        else:
            chrome_options = webdriver.ChromeOptions()
            chrome_options.add_argument('--headless')
            chrome_options.add_argument('--no-sandbox')
            chrome_options.add_argument('--disable-gpu')
            chrome_options.add_argument('--disable-extensions')
            chrome_options.add_argument('--disable-dev-shm-usage')
            chrome_options.add_argument('--disable-blink-features=AutomationControlled')
            driver = webdriver.Chrome(options=chrome_options)

            driver.set_page_load_timeout(10)
            driver.get(url)
            soup = BeautifulSoup(driver.page_source, 'lxml')
            driver.quit()
            del driver
            gc.collect()

        for script in soup(["script", "style"]):
            script.extract()

        text = soup.get_text()

        lines = (line.strip() for line in text.splitlines())
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        text = '\n'.join(chunk for chunk in chunks if chunk).replace('-\n', '').lower()
        text = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', text)
        text = ''.join([i for i in text if not i.isdigit()])

        text = list(np.concatenate([sent_tokenize(i.strip()) for i in text.split('\n')]).flat)

        text_lemmatized = []
        for line in [t.split() for t in text]:
            line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
            text_lemmatized.append(line_lemmatized)

        spans = list(filter(None, [span.string for span in soup.find_all('span')]))

        if len(spans):
            spans = '\n'.join(span for span in spans if span).replace('-\n', '').lower()
            spans = re.sub(r'[`!@#$%^&*()_+\-=\[\]{};\':"\\|,.<>\/?~©«»—]', r'', spans)
            spans = ''.join([i for i in spans if not i.isdigit()])

            spans = list(np.concatenate([sent_tokenize(i.strip()) for i in spans.split('\n')]).flat)
        else:
            spans = []

        spans_lemmatized = []
        for line in [s.split() for s in spans]:
            line_lemmatized = ' '.join([morph.normal_forms(l)[0] for l in line if l not in stopwords_ru])
            spans_lemmatized.append(line_lemmatized)

        df1 = pd.DataFrame(text_lemmatized, columns=['text'])
        df2 = pd.DataFrame(spans_lemmatized, columns=['text'])
        data = pd.concat([df1, df2]).drop_duplicates().reset_index(drop=True)
        data['company'] = company
        data['url'] = url
        data = data[['company', 'url', 'text']]

        return data

# %%
def chunkify(data, chunk_size):
    it = iter(data)
    for i in range(0, len(data), chunk_size):
        yield {k: data[k] for k in [next(it) for _ in range(min(chunk_size, len(data) - i))]}

def process_chunk(URLs_chunk, enum, function):
    with ThreadPoolExecutor(4) as executor:
        chunk_res = pd.DataFrame()
        results = {executor.submit(function, company, url): (url, company) for url, company in URLs_chunk.items()}
        for i, result in enumerate(as_completed(results)):
            try:
                url, company = results[result]
                df1 = result.result()
                chunk_res = pd.concat([chunk_res, df1])
                print('DONE', i+enum, company)
            except Exception as err:
                print('ERROR', i+enum, company, err)
                continue
    return chunk_res, i+enum+1

# %%
def zip_folder(folder_path, output_path):
    with zipfile.ZipFile(output_path, 'w') as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), folder_path))

# %%
stopwords_ru = stopwords.words("russian")
morph = MorphAnalyzer()

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    "accept": "application/xml"
}

timeout = (5, 25)

# %%
raex_list = pd.read_excel("RAEX2024.xlsx")

url = 'https://docs.google.com/spreadsheets/d/1uUgKmlYBCWxFTMvbcwKQDCblTQhKOsZ_zPs0VCRQBEE/export?format=xlsx'
response = requests.get(url)

excel = pd.ExcelFile(BytesIO(response.content))
sheets = excel.sheet_names
sheets
# Out:
# ['Методика',
#  'Компании СЗ+RAEX',
#  'Copy of Компании СЗ',
#  'Общий отраслевой рейтинг',
#  'Региональный отраслевой рейтинг',
#  'Общий глобальный рейтинг ',
#  'Региональный глобальный рейтинг',
#  'База данных',
#  'Copy of Ранги и места',
#  'Компании RAEX',
#  'MOEX',
#  'Технический лист',
#  'Sheet13',
#  'Sheet14',
#  'Sheet15']

# %%
data = pd.read_excel(excel, sheet_name='Компании СЗ+RAEX')
data.drop(['Unnamed: 0', 'Unnamed: 17', 'Unnamed: 18'], axis=1, inplace=True)
data.columns = ['Отрасль', 'Бренд и Юрлицо', 'Веб-сайт', 'ИНН', 'МOEX', 'Регион', 'Устойчивое развитие, Социальная отчетность, ESG', 'Экология', 'Забота о потребителях, защита прав потребителей',
                'Забота о работниках, социальные программы', 'Поставщикам, Закупки', 'Корпоративное управление, совет директоров, высший менеджмент',
                'Миссия, ценности', 'Этический кодекс', 'Антикоррупция', 'Раскрытие информации']
data = data.drop([0, 1], axis=0).reset_index(drop=True)
data['Отрасль'] = data['Отрасль'].fillna(method='ffill')
#data = data[data['Регион'] == 'RAEX']
data = data.rename(columns={'Бренд и Юрлицо': 'Название'})
data = data.drop_duplicates(subset=['Название']).reset_index(drop=True)
data.loc[data['Название'] == 'СБЕРБАНК', 'Название'] = 'Сбербанк'
data.loc[data['Название'] == 'Х5 (Вятерочка, Перекресток)', 'Название'] = 'X5 Group'
data.loc[data['Название'] == 'МТС', 'Название'] = 'ПАО "МТС"'
data.loc[data['Название'] == 'Билайн (Вымпелком СЗФО)', 'Название'] = '«Вымпелком»'
data.loc[data['Название'] == 'Segezha Group', 'Название'] = 'Сегежа Групп'
data.loc[data['Название'] == 'ГК “Самолет”', 'Название'] = 'ГК «САМОЛЕТ»'
data.loc[data['Название'] == 'АО "Группа "Илим"', 'Название'] = '«Илим», группа'
data.loc[data['Название'] == 'Группа ЛСР', 'Название'] = '«Группа ЛСР»'
data.loc[data['Название'] == 'ЛЕНТА', 'Название'] = '«Лента» (сеть гипермаркетов)'
data.loc[data['Название'] == 'Ростелеком', 'Название'] = '«Ростелеком»'
data.loc[data['Название'] == 'МАГНИТ', 'Название'] = '«Магнит», розничная сеть'
data.loc[data['Название'] == 'ВТБ', 'Название'] = 'Банк ВТБ'
data.loc[data['Название'] == 'СВЕЗА', 'Название'] = 'Свеза'
data.loc[data['Название'] == 'Мегафон', 'Название'] = '«МегаФон»'
data.loc[data['Название'] == '"Альфа-Банк"', 'Название'] = 'Альфа-Банк'
data.loc[data['Название'] == '"Открытие"', 'Название'] = '«ФК Открытие»'
data.loc[data['Название'] == 'ПСБ по СЗФО', 'Название'] = 'Промсвязьбанк'
data.loc[data['Название'] == '"ВкусВилл"', 'Название'] = '«Вкусвилл»'
data.loc[data['Название'] == '«Карелия Палп»', 'Название'] = 'Карелия Палп'
data.loc[data['Название'] == 'Азбука вкуса', 'Название'] = '«Азбука Вкуса» (сеть супермаркетов)'

data = raex_list.merge(data, on='Название', how='left')
data.drop(['url', 'url_sustainability'], axis=1, inplace=True)
data
# Out:
#            №                       Название Код MOEX  \
# 0          1                       Сбербанк     SBER
# 1          2                      «ФосАгро»     PHOR
# 2          3                        «Полюс»     PLZL
# 3          4             «Татнефть», группа     TATN
# 4          5  «Роснефть», нефтяная компания     ROSN
# ..       ...                            ...      ...
# 155      156                    Новикомбанк        -
# 156  157-160                       «Квадра»     TGKD
# 157  157-160      «Русская медная компания»        -
# 158  157-160                         «УГМК»        -
# 159  157-160          «Упаковочные системы»        -
#
#                                 Подотрасль ESG-рейтинг   E Rank E-рейтинг  \
# 0                                    Банки          AA        2        AA
# 1                             Агрохимикаты          AA        5        AA
# 2                      Драгоценные металлы          AA        1        AA
# 3    Интегрированные нефтегазовые компании          AA       13         A
# 4    Интегрированные нефтегазовые компании          AA        4        AA
# ..                                     ...         ...      ...       ...
# 155                                  Банки           C      114         C
# 156                      Электроэнергетика           M  157-160         M
# 157                      Производство меди           M  157-160         M
# 158      Добыча прочих полезных ископаемых           M  157-160         M
# 159                    Упаковочные решения           M  157-160         M
#
#       S Rank S-рейтинг   G Rank  ...  \
# 0          1       AAA        4  ...
# 1          3        AA        2  ...
# 2          2        AA       14  ...
# 3          5        AA        6  ...
# 4         22         A        5  ...
# ..       ...       ...      ...  ...
# 155      145         C  155-156  ...
# 156  157-160         M  157-160  ...
# 157  157-160         M  157-160  ...
# 158  157-160         M  157-160  ...
# 159  157-160         M  157-160  ...
#
#        Устойчивое развитие, Социальная отчетность, ESG  \
# 0           https://www.sberbank.com/ru/sustainability
# 1              https://www.phosagro.ru/sustainability/
# 2                https://sustainability.polyus.com/ru/
# 3       https://www.tatneft.ru/sustainable_development
# 4                              Rosneft_CSR2022_RUS.pdf
# ..                                                 ...
# 155  https://ar2021.novikom.ru/ru/sustainable-devel...
# 156  https://www.quadra.ru/o-kompanii/sotsialnoe-ra...
# 157  https://rmk-group.ru/ru/sustainable_developmen...
# 158           https://ugmk.com/about_company/strategy/
# 159      https://www.packaging-systems.ru/sustainable/
#
#                                               Экология  \
# 0           https://www.sberbank.com/ru/sustainability
# 1      https://www.phosagro.ru/sustainability/ecology/
# 2    https://sustainability.polyus.com/ru/environment/
# 3                     https://www.tatneft.ru/ekologiya
# 4                                                  Нет
# ..                                                 ...
# 155                                                Нет
# 156  https://www.quadra.ru/o-kompanii/sotsialnoe-ra...
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159      https://www.packaging-systems.ru/sustainable/
#
#        Забота о потребителях, защита прав потребителей  \
# 0    https://www.sberbank.com/common/img/uploaded/r...
# 1        https://www.phosagro.ru/production/attention/
# 2    https://sustainability.polyus.com/ru/human_rig...
# 3    https://www.tatneft.ru/sustainable_development...
# 4                                                  Нет
# ..                                                 ...
# 155                                                Нет
# 156                                                нет
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159                                                нет
#
#              Забота о работниках, социальные программы  \
# 0                               https://rabota.sber.ru
# 1    https://www.phosagro.ru/sustainability/social-...
# 2     https://sustainability.polyus.com/ru/our_people/
# 3    https://www.tatneft.ru/sustainable_development...
# 4    https://www.rosneft.ru/Development/personnel/ ...
# ..                                                 ...
# 155                                                Нет
# 156  https://www.quadra.ru/o-kompanii/sotsialnoe-ra...
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159                                                нет
#
#                      Поставщикам, Закупки  \
# 0                                     Нет
# 1    https://www.phosagro.ru/procurement/
# 2                                     нет
# 3                                     Нет
# 4                                     Нет
# ..                                    ...
# 155           https://novikom.ru/tenders/
# 156    https://www.quadra.ru/trade/legal/
# 157                      сайт не работает
# 158                      сайт не работает
# 159                                   нет
#
#     Корпоративное управление, совет директоров, высший менеджмент  \
# 0    https://www.sberbank.com/ru/investor-relations...
# 1            https://www.phosagro.ru/about/management/
# 2    https://polyus.com/ru/company/corporate_govern...
# 3    https://www.tatneft.ru/o-kompanii/corporate_go...
# 4                   https://www.rosneft.ru/governance/
# ..                                                 ...
# 155  https://novikom.ru/about/ustav-i-vnutrennie-do...
# 156  https://www.quadra.ru/aktsioneram-i-investoram...
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159                                                нет
#
#                                Миссия, ценности  \
# 0     https://www.sberbank.com/ru/about/mission
# 1       https://www.phosagro.ru/sustainability/
# 2                                           нет
# 3     https://www.tatneft.ru/o-kompanii/mission
# 4        https://www.rosneft.ru/about/strategy/
# ..                                          ...
# 155                                         нет
# 156                                         нет
# 157                            сайт не работает
# 158                            сайт не работает
# 159  https://www.packaging-systems.ru/#missions
#
#                                       Этический кодекс  \
# 0             https://www.sberbank.com/ru/about/ethics
# 1    https://ar2022.phosagro.ru/pdf/ar/ru/corporate...
# 2                                                  нет
# 3                                                  нет
# 4            https://www.rosneft.ru/Investors/corpgov/
# ..                                                 ...
# 155                                                нет
# 156                                                нет
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159                                                нет
#
#                                          Антикоррупция  \
# 0         https://www.sberbank.com/ru/compliance/ukipk
# 1                                                  нет
# 2               https://polyus.com/ru/anti-corruption/
# 3    https://www.tatneft.ru/o-kompanii/corporate_go...
# 4            https://www.rosneft.ru/Investors/corpgov/
# ..                                                 ...
# 155                https://novikom.ru/anti-corruption/
# 156  https://www.quadra.ru/o-kompanii/protivodejstv...
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159                                                нет
#
#                                   Раскрытие информации
# 0    https://www.sberbank.com/ru/investor-relations...
# 1    https://www.phosagro.ru/ori/phosagro/company_c...
# 2                                                  нет
# 3    https://www.tatneft.ru/aktsioneram-i-investora...
# 4        https://www.rosneft.ru/Investors/information/
# ..                                                 ...
# 155         https://novikom.ru/information-disclosure/
# 156  https://www.quadra.ru/aktsioneram-i-investoram...
# 157                                   сайт не работает
# 158                                   сайт не работает
# 159                                                нет
#
# [160 rows x 27 columns]

# %%
df = data.melt(id_vars=['№', 'Название'], value_vars=['Устойчивое развитие, Социальная отчетность, ESG', 'Экология', 'Забота о потребителях, защита прав потребителей',
                'Забота о работниках, социальные программы', 'Поставщикам, Закупки', 'Корпоративное управление, совет директоров, высший менеджмент',
                'Миссия, ценности', 'Этический кодекс', 'Антикоррупция', 'Раскрытие информации'], var_name='url_type', value_name='url')
df = df.drop(columns=['url_type'])
df
# Out:
#             №                       Название  \
# 0           1                       Сбербанк
# 1           2                      «ФосАгро»
# 2           3                        «Полюс»
# 3           4             «Татнефть», группа
# 4           5  «Роснефть», нефтяная компания
# ...       ...                            ...
# 1595      156                    Новикомбанк
# 1596  157-160                       «Квадра»
# 1597  157-160      «Русская медная компания»
# 1598  157-160                         «УГМК»
# 1599  157-160          «Упаковочные системы»
#
#                                                     url
# 0            https://www.sberbank.com/ru/sustainability
# 1               https://www.phosagro.ru/sustainability/
# 2                 https://sustainability.polyus.com/ru/
# 3        https://www.tatneft.ru/sustainable_development
# 4                               Rosneft_CSR2022_RUS.pdf
# ...                                                 ...
# 1595         https://novikom.ru/information-disclosure/
# 1596  https://www.quadra.ru/aktsioneram-i-investoram...
# 1597                                   сайт не работает
# 1598                                   сайт не работает
# 1599                                                нет
#
# [1600 rows x 3 columns]

# %%
words_to_filter = ['Нет', 'нет', 'не работает']
pattern = '|'.join(words_to_filter)

df['url'] = df['url'].apply(lambda x: np.nan if pd.notna(x) and pd.Series(x).str.contains(pattern).any() else x)
df = df.dropna(subset=["url"])
df['url'] = df['url'].apply(clear_string)
df = df.explode('url')
df = df.sort_values(by='Название').reset_index(drop=True)
df
# Out:
#       №                                          Название  \
# 0    60                          "Каустик" (г. Волгоград)
# 1    60                          "Каустик" (г. Волгоград)
# 2    60                          "Каустик" (г. Волгоград)
# 3    60                          "Каустик" (г. Волгоград)
# 4    60                          "Каустик" (г. Волгоград)
# ..   ..                                               ...
# 892  50  Якутская топливно-энергетическая компания (ЯТЭК)
# 893  50  Якутская топливно-энергетическая компания (ЯТЭК)
# 894  50  Якутская топливно-энергетическая компания (ЯТЭК)
# 895  50  Якутская топливно-энергетическая компания (ЯТЭК)
# 896  50  Якутская топливно-энергетическая компания (ЯТЭК)
#
#                                                    url
# 0    https://www.kaustik.ru/ru/index.php/partneram/...
# 1                    sustainability-report-kaustik.pdf
# 2    https://www.kaustik.ru/ru/index.php/o-kompanii...
# 3    https://www.kaustik.ru/ru/index.php/o-kompanii...
# 4    https://www.kaustik.ru/ru/index.php/o-kompanii...
# ..                                                 ...
# 892  https://yatec.ru/postavshchikam/tekushchie-zak...
# 893  https://www.yatec.ru/aktsioneram/raskrytie-inf...
# 894  https://yatec.ru/aktsioneram/raskrytie-informa...
# 895                 https://yatec.ru/razvitie/ecology/
# 896                  https://yatec.ru/razvitie/safety/
#
# [897 rows x 3 columns]

# %%
urls = df.set_index('url')['Название'].to_dict()
len(urls)
# Out:
# 818

# %%
folder_name = 'PDFs'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
# %%time
chunk_size = 5
links = pd.DataFrame()
i = 0
for URLs_chunk in chunkify(urls, chunk_size):
    chunk_results, i = process_chunk(URLs_chunk, i, get_all_links)
    try:
        links = pd.concat([links, chunk_results])
        del chunk_results
        gc.collect()
    except Exception as err:
        continue

print("Links are collected!")

links = links.drop_duplicates().reset_index(drop=True)

words_to_filter = ['.xlsx', '.docx', '.7z', '.rar', '.JPG', '.xlsb', '.xls', '.zip', '.mp4', '.jpg', '.png', '.doc', '.PNG', 'download_file.php']
links = links[~links['urls'].str.contains('|'.join(words_to_filter))].reset_index(drop=True)
links.to_csv('links.csv', encoding='utf-8')
# Out:
# DONE 0 "Каустик" (г. Волгоград)
# DONE 1 "Каустик" (г. Волгоград)
# DONE 2 "Каустик" (г. Волгоград)
# DONE 3 "Каустик" (г. Волгоград)
# DONE 4 "Каустик" (г. Волгоград)
# DONE 5 "Нефтиса", нефтяная компания
# DONE 6 "Нефтиса", нефтяная компания
# DONE 7 "Нефтиса", нефтяная компания
# DONE 8 "Каустик" (г. Волгоград)
# DONE 9 "Каустик" (г. Волгоград)
# DONE 10 "Нефтиса", нефтяная компания
# DONE 11 "Нефтиса", нефтяная компания
# DONE 12 "Соликамскбумпром"
# DONE 13 "Соликамскбумпром"
# DONE 14 "Соликамскбумпром"
# DONE 15 "Соликамскбумпром"
# DONE 16 "Соликамскбумпром"
# DONE 17 «Титан», группа компаний (нефтехимия)
# DONE 18 «Титан», группа компаний (нефтехимия)
# DONE 19 "Титан", группа компаний (деревообработка)
# DONE 20 "Титан", группа компаний (деревообработка)
# DONE 21 "Титан", группа компаний (деревообработка)
# DONE 22 En+ Group
# DONE 23 En+ Group
# DONE 24 En+ Group
# DONE 25 En+ Group
# DONE 26 En+ Group
# DONE 27 Global Ports
# DONE 28 Global Ports
# DONE 29 En+ Group
# DONE 30 Global Ports
# DONE 31 Global Ports
# DONE 32 Global Ports
# DONE 33 Global Ports
# DONE 34 Globaltrans
# DONE 35 Globaltrans
# DONE 36 Globaltrans
# DONE 37 Globaltrans
# DONE 38 Globaltrans
# DONE 39 Highland Gold Mining
# DONE 40 Highland Gold Mining
# DONE 41 Highland Gold Mining
# DONE 42 Nordgold
# DONE 43 Nordgold
# DONE 44 Nordgold
# DONE 45 Nordgold
# DONE 46 Nordgold
# DONE 47 Nordgold
# DONE 48 Nordgold
# DONE 49 Positive Technologies
# DONE 50 S7 Airlines
# DONE 51 S7 Airlines
# DONE 52 Positive Technologies
# DONE 53 S7 Airlines
# DONE 54 S7 Airlines
# DONE 55 VK
# DONE 56 VK
# DONE 57 X5 Group
# DONE 58 VK
# DONE 59 X5 Group
# DONE 60 X5 Group
# DONE 61 X5 Group
# DONE 62 X5 Group
# DONE 63 X5 Group
# DONE 64 X5 Group
# ERROR 65 «АК БАРС» БАНК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5977ca7a1e9a <unknown>
# #1 0x5977ca48b45c <unknown>
# #2 0x5977ca482fd0 <unknown>
# #3 0x5977ca472b32 <unknown>
# #4 0x5977ca474162 <unknown>
# #5 0x5977ca472ded <unknown>
# #6 0x5977ca472503 <unknown>
# #7 0x5977ca4723f5 <unknown>
# #8 0x5977ca470336 <unknown>
# #9 0x5977ca47083a <unknown>
# #10 0x5977ca48dea7 <unknown>
# #11 0x5977ca519ed5 <unknown>
# #12 0x5977ca4fa4b2 <unknown>
# #13 0x5977ca5192cc <unknown>
# #14 0x5977ca4fa253 <unknown>
# #15 0x5977ca4ca1c7 <unknown>
# #16 0x5977ca4cab3e <unknown>
# #17 0x5977ca7682db <unknown>
# #18 0x5977ca76c387 <unknown>
# #19 0x5977ca754e0e <unknown>
# #20 0x5977ca76ce52 <unknown>
# #21 0x5977ca7397af <unknown>
# #22 0x5977ca791188 <unknown>
# #23 0x5977ca79135b <unknown>
# #24 0x5977ca7a0fcc <unknown>
# #25 0x7a8903d51ac3 <unknown>
#
# ERROR 66 «АК БАРС» БАНК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x58b715bfee9a <unknown>
# #1 0x58b7158e845c <unknown>
# #2 0x58b7158dffd0 <unknown>
# #3 0x58b7158cfb32 <unknown>
# #4 0x58b7158d1162 <unknown>
# #5 0x58b7158cfded <unknown>
# #6 0x58b7158cf503 <unknown>
# #7 0x58b7158cf3f5 <unknown>
# #8 0x58b7158cd336 <unknown>
# #9 0x58b7158cd83a <unknown>
# #10 0x58b7158eaea7 <unknown>
# #11 0x58b715976ed5 <unknown>
# #12 0x58b7159574b2 <unknown>
# #13 0x58b7159762cc <unknown>
# #14 0x58b715957253 <unknown>
# #15 0x58b7159271c7 <unknown>
# #16 0x58b715927b3e <unknown>
# #17 0x58b715bc52db <unknown>
# #18 0x58b715bc9387 <unknown>
# #19 0x58b715bb1e0e <unknown>
# #20 0x58b715bc9e52 <unknown>
# #21 0x58b715b967af <unknown>
# #22 0x58b715bee188 <unknown>
# #23 0x58b715bee35b <unknown>
# #24 0x58b715bfdfcc <unknown>
# #25 0x7d9ad7229ac3 <unknown>
#
# ERROR 67 «АК БАРС» БАНК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5d469f74ee9a <unknown>
# #1 0x5d469f43845c <unknown>
# #2 0x5d469f42ffd0 <unknown>
# #3 0x5d469f41fb32 <unknown>
# #4 0x5d469f421162 <unknown>
# #5 0x5d469f41fded <unknown>
# #6 0x5d469f41f503 <unknown>
# #7 0x5d469f41f3f5 <unknown>
# #8 0x5d469f41d336 <unknown>
# #9 0x5d469f41d83a <unknown>
# #10 0x5d469f43aea7 <unknown>
# #11 0x5d469f4c6ed5 <unknown>
# #12 0x5d469f4a74b2 <unknown>
# #13 0x5d469f4c62cc <unknown>
# #14 0x5d469f4a7253 <unknown>
# #15 0x5d469f4771c7 <unknown>
# #16 0x5d469f477b3e <unknown>
# #17 0x5d469f7152db <unknown>
# #18 0x5d469f719387 <unknown>
# #19 0x5d469f701e0e <unknown>
# #20 0x5d469f719e52 <unknown>
# #21 0x5d469f6e67af <unknown>
# #22 0x5d469f73e188 <unknown>
# #23 0x5d469f73e35b <unknown>
# #24 0x5d469f74dfcc <unknown>
# #25 0x7974cadd3ac3 <unknown>
#
# ERROR 68 «АК БАРС» БАНК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x590092d56e9a <unknown>
# #1 0x590092a4045c <unknown>
# #2 0x590092a37fd0 <unknown>
# #3 0x590092a27b32 <unknown>
# #4 0x590092a29162 <unknown>
# #5 0x590092a27ded <unknown>
# #6 0x590092a27503 <unknown>
# #7 0x590092a273f5 <unknown>
# #8 0x590092a25336 <unknown>
# #9 0x590092a2583a <unknown>
# #10 0x590092a42ea7 <unknown>
# #11 0x590092aceed5 <unknown>
# #12 0x590092aaf4b2 <unknown>
# #13 0x590092ace2cc <unknown>
# #14 0x590092aaf253 <unknown>
# #15 0x590092a7f1c7 <unknown>
# #16 0x590092a7fb3e <unknown>
# #17 0x590092d1d2db <unknown>
# #18 0x590092d21387 <unknown>
# #19 0x590092d09e0e <unknown>
# #20 0x590092d21e52 <unknown>
# #21 0x590092cee7af <unknown>
# #22 0x590092d46188 <unknown>
# #23 0x590092d4635b <unknown>
# #24 0x590092d55fcc <unknown>
# #25 0x7b8415ae9ac3 <unknown>
#
# ERROR 69 «АК БАРС» БАНК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x
# DONE 111 «Вымпелком»
# DONE 112 «Вкусвилл»
# DONE 113 «Вкусвилл»
# DONE 114 «Вымпелком»
# DONE 115 «Вымпелком»
# DONE 116 «Вымпелком»
# DONE 117 «Вымпелком»
# DONE 118 «Вымпелком»
# DONE 119 «Высочайший» (GV Gold)
# DONE 120 «Высочайший» (GV Gold)
# DONE 121 «Высочайший» (GV Gold)
# DONE 122 «Высочайший» (GV Gold)
# ERROR 123 «Газпром нефть» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5b7cf4ce0e9a <unknown>
# #1 0x5b7cf49ca45c <unknown>
# #2 0x5b7cf49c1fd0 <unknown>
# #3 0x5b7cf49b1b32 <unknown>
# #4 0x5b7cf49b3162 <unknown>
# #5 0x5b7cf49b1ded <unknown>
# #6 0x5b7cf49b1503 <unknown>
# #7 0x5b7cf49b13f5 <unknown>
# #8 0x5b7cf49af336 <unknown>
# #9 0x5b7cf49af83a <unknown>
# #10 0x5b7cf49ccea7 <unknown>
# #11 0x5b7cf4a58ed5 <unknown>
# #12 0x5b7cf4a394b2 <unknown>
# #13 0x5b7cf4a582cc <unknown>
# #14 0x5b7cf4a39253 <unknown>
# #15 0x5b7cf4a091c7 <unknown>
# #16 0x5b7cf4a09b3e <unknown>
# #17 0x5b7cf4ca72db <unknown>
# #18 0x5b7cf4cab387 <unknown>
# #19 0x5b7cf4c93e0e <unknown>
# #20 0x5b7cf4cabe52 <unknown>
# #21 0x5b7cf4c787af <unknown>
# #22 0x5b7cf4cd0188 <unknown>
# #23 0x5b7cf4cd035b <unknown>
# #24 0x5b7cf4cdffcc <unknown>
# #25 0x78ad7e0f9ac3 <unknown>
#
# ERROR 124 «Газпром нефть» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5bbc39411e9a <unknown>
# #1 0x5bbc390fb45c <unknown>
# #2 0x5bbc390f2fd0 <unknown>
# #3 0x5bbc390e2b32 <unknown>
# #4 0x5bbc390e4162 <unknown>
# #5 0x5bbc390e2ded <unknown>
# #6 0x5bbc390e2503 <unknown>
# #7 0x5bbc390e23f5 <unknown>
# #8 0x5bbc390e0336 <unknown>
# #9 0x5bbc390e083a <unknown>
# #10 0x5bbc390fdea7 <unknown>
# #11 0x5bbc39189ed5 <unknown>
# #12 0x5bbc3916a4b2 <unknown>
# #13 0x5bbc391892cc <unknown>
# #14 0x5bbc3916a253 <unknown>
# #15 0x5bbc3913a1c7 <unknown>
# #16 0x5bbc3913ab3e <unknown>
# #17 0x5bbc393d82db <unknown>
# #18 0x5bbc393dc387 <unknown>
# #19 0x5bbc393c4e0e <unknown>
# #20 0x5bbc393dce52 <unknown>
# #21 0x5bbc393a97af <unknown>
# #22 0x5bbc39401188 <unknown>
# #23 0x5bbc3940135b <unknown>
# #24 0x5bbc39410fcc <unknown>
# #25 0x7a05b8d28ac3 <unknown>
#
# ERROR 125 «Газпром нефть» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5a7127e9ae9a <unknown>
# #1 0x5a7127b8445c <unknown>
# #2 0x5a7127b7bfd0 <unknown>
# #3 0x5a7127b6bb32 <unknown>
# #4 0x5a7127b6d162 <unknown>
# #5 0x5a7127b6bded <unknown>
# #6 0x5a7127b6b503 <unknown>
# #7 0x5a7127b6b3f5 <unknown>
# #8 0x5a7127b69336 <unknown>
# #9 0x5a7127b6983a <unknown>
# #10 0x5a7127b86ea7 <unknown>
# #11 0x5a7127c12ed5 <unknown>
# #12 0x5a7127bf34b2 <unknown>
# #13 0x5a7127c122cc <unknown>
# #14 0x5a7127bf3253 <unknown>
# #15 0x5a7127bc31c7 <unknown>
# #16 0x5a7127bc3b3e <unknown>
# #17 0x5a7127e612db <unknown>
# #18 0x5a7127e65387 <unknown>
# #19 0x5a7127e4de0e <unknown>
# #20 0x5a7127e65e52 <unknown>
# #21 0x5a7127e327af <unknown>
# #22 0x5a7127e8a188 <unknown>
# #23 0x5a7127e8a35b <unknown>
# #24 0x5a7127e99fcc <unknown>
# #25 0x7d2168023ac3 <unknown>
#
# ERROR 126 «Газпром» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5bad3cd87e9a <unknown>
# #1 0x5bad3ca7145c <unknown>
# #2 0x5bad3ca68fd0 <unknown>
# #3 0x5bad3ca58b32 <unknown>
# #4 0x5bad3ca5a162 <unknown>
# #5 0x5bad3ca58ded <unknown>
# #6 0x5bad3ca58503 <unknown>
# #7 0x5bad3ca583f5 <unknown>
# #8 0x5bad3ca56336 <unknown>
# #9 0x5bad3ca5683a <unknown>
# #10 0x5bad3ca73ea7 <unknown>
# #11 0x5bad3caffed5 <unknown>
# #12 0x5bad3cae04b2 <unknown>
# #13 0x5bad3caff2cc <unknown>
# #14 0x5bad3cae0253 <unknown>
# #15 0x5bad3cab01c7 <unknown>
# #16 0x5bad3cab0b3e <unknown>
# #17 0x5bad3cd4e2db <unknown>
# #18 0x5bad3cd52387 <unknown>
# #19 0x5bad3cd3ae0e <unknown>
# #20 0x5bad3cd52e52 <unknown>
# #21 0x5bad3cd1f7af <unknown>
# #22 0x5bad3cd77188 <unknown>
# #23 0x5bad3cd7735b <unknown>
# #24 0x5bad3cd86fcc <unknown>
# #25 0x7f9bfe55cac3 <unknown>
#
# ERROR 127 «Газпром нефть» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x555d2ff5fe9a <unknown>
# #1 0x555d2fc4945c <unknown>
# #2 0x555d2fc40fd0 <unknown>
# #3 0x555d2fc30b32 <unknown>
# #4 0x555d2fc32162 <unknown>
# #5 0x555d2fc30ded <unknown>
# #6 0x555d2fc30503 <unknown>
# #7 0x555d2fc303f5 <unknown>
# #8 0x555d2fc2e336 <unknown>
# #9 0x555d2fc2e83a <unknown>
# #10 0x555d2fc4bea7 <unknown>
# #11 0x555d2fcd7ed5 <unknown>
# #12 0x555d2fcb84b2 <unknown>
# #13 0x555d2fcd72cc <unknown>
# #14 0x555d2fcb8253 <unknown>
# #15 0x555d2fc881c7 <unknown>
# #16 0x555d2fc88b3e <unknown>
# #17 0x555d2ff262db <unknown>
# #18 0x555d2ff2a387 <unknown>
# #19 0x555d2ff12e0e <unknown>
# #20 0x555d2ff2ae52 <unknown>
# #21 0x555d2fef77af <unknown>
# #22 0x555d2ff4f188 <unknown>
# #23 0x555d2ff4f35b <unknown>
# #24 0x555d2ff5efcc <unknown>
# #25 0x7dc2769a0ac3 <unknown>
#
# ERROR 128 «Газпром нефть» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0
Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x58927e37de9a <unknown>
# #1 0x58927e06745c <unknown>
# #2 0x58927e05efd0 <unknown>
# #3 0x58927e04eb32 <unknown>
# #4 0x58927e050162 <unknown>
# #5 0x58927e04eded <unknown>
# #6 0x58927e04e503 <unknown>
# #7 0x58927e04e3f5 <unknown>
# #8 0x58927e04c336 <unknown>
# #9 0x58927e04c83a <unknown>
# #10 0x58927e069ea7 <unknown>
# #11 0x58927e0f5ed5 <unknown>
# #12 0x58927e0d64b2 <unknown>
# #13 0x58927e0f52cc <unknown>
# #14 0x58927e0d6253 <unknown>
# #15 0x58927e0a61c7 <unknown>
# #16 0x58927e0a6b3e <unknown>
# #17 0x58927e3442db <unknown>
# #18 0x58927e348387 <unknown>
# #19 0x58927e330e0e <unknown>
# #20 0x58927e348e52 <unknown>
# #21 0x58927e3157af <unknown>
# #22 0x58927e36d188 <unknown>
# #23 0x58927e36d35b <unknown>
# #24 0x58927e37cfcc <unknown>
# #25 0x7c2301fc0ac3 <unknown>
#
# ERROR 132 «Газпром» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5c9956d2fe9a <unknown>
# #1 0x5c9956a1945c <unknown>
# #2 0x5c9956a10fd0 <unknown>
# #3 0x5c9956a00b32 <unknown>
# #4 0x5c9956a02162 <unknown>
# #5 0x5c9956a00ded <unknown>
# #6 0x5c9956a00503 <unknown>
# #7 0x5c9956a003f5 <unknown>
# #8 0x5c99569fe336 <unknown>
# #9 0x5c99569fe83a <unknown>
# #10 0x5c9956a1bea7 <unknown>
# #11 0x5c9956aa7ed5 <unknown>
# #12 0x5c9956a884b2 <unknown>
# #13 0x5c9956aa72cc <unknown>
# #14 0x5c9956a88253 <unknown>
# #15 0x5c9956a581c7 <unknown>
# #16 0x5c9956a58b3e <unknown>
# #17 0x5c9956cf62db <unknown>
# #18 0x5c9956cfa387 <unknown>
# #19 0x5c9956ce2e0e <unknown>
# #20 0x5c9956cfae52 <unknown>
# #21 0x5c9956cc77af <unknown>
# #22 0x5c9956d1f188 <unknown>
# #23 0x5c9956d1f35b <unknown>
# #24 0x5c9956d2efcc <unknown>
# #25 0x7bc098122ac3 <unknown>
#
# ERROR 133 «Газпром» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x578a83641e9a <unknown>
# #1 0x578a8332b45c <unknown>
# #2 0x578a83322fd0 <unknown>
# #3 0x578a83312b32 <unknown>
# #4 0x578a83314162 <unknown>
# #5 0x578a83312ded <unknown>
# #6 0x578a83312503 <unknown>
# #7 0x578a833123f5 <unknown>
# #8 0x578a83310336 <unknown>
# #9 0x578a8331083a <unknown>
# #10 0x578a8332dea7 <unknown>
# #11 0x578a833b9ed5 <unknown>
# #12 0x578a8339a4b2 <unknown>
# #13 0x578a833b92cc <unknown>
# #14 0x578a8339a253 <unknown>
# #15 0x578a8336a1c7 <unknown>
# #16 0x578a8336ab3e <unknown>
# #17 0x578a836082db <unknown>
# #18 0x578a8360c387 <unknown>
# #19 0x578a835f4e0e <unknown>
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x58ae436d2e9a <unknown>
# #1 0x58ae433bc2a1 <unknown>
# #2 0x58ae433a2973 <unknown>
# #3 0x58ae433a11b8 <unknown>
# #4 0x58ae433a183a <unknown>
# #5 0x58ae433beea7 <unknown>
# #6 0x58ae4344aed5 <unknown>
# #7 0x58ae4342b4b2 <unknown>
# #8 0x58ae4344a2cc <unknown>
# #9 0x58ae4342b253 <unknown>
# #10 0x58ae433fb1c7 <unknown>
# #11 0x58ae433fbb3e <unknown>
# #12 0x58ae436992db <unknown>
# #13 0x58ae4369d387 <unknown>
# #14 0x58ae43685e0e <unknown>
# #15 0x58ae4369de52 <unknown>
# #16 0x58ae4366a7af <unknown>
# #17 0x58ae436c2188 <unknown>
# #18 0x58ae436c235b <unknown>
# #19 0x58ae436d1fcc <unknown>
# #20 0x78dce9ab5ac3 <unknown>
#
# DONE 196 «КамАЗ»
# DONE 197 «КамАЗ»
# DONE 198 «КамАЗ»
# DONE 199 «Квадра»
# DONE 200 «Квадра»
# DONE 201 «Квадра»
# DONE 202 «Квадра»
# DONE 203 «Квадра»
# DONE 204 «Квадра»
# DONE 205 «Корпорация ВСМПО-АВИСМА»
# DONE 206 «Квадра»
# DONE 207 «Корпорация ВСМПО-АВИСМА»
# DONE 208 «Корпорация ВСМПО-АВИСМА»
# DONE 209 «Корпорация ВСМПО-АВИСМА»
# DONE 210 «Корпорация ВСМПО-АВИСМА»
# DONE 211 «Красноярский завод цветных металлов имени В.Н. Гулидова»
# DONE 212 «Красноярский завод цветных металлов имени В.Н. Гулидова»
# DONE 213 «Красноярский завод цветных металлов имени В.Н. Гулидова»
# DONE 214 «Красноярский завод цветных металлов имени В.Н. Гулидова»
# DONE 215 «КуйбышевАзот»
# DONE 216 «КуйбышевАзот»
# DONE 217 «КуйбышевАзот»
# DONE 218 «КуйбышевАзот»
# DONE 219 «Кузбассразрезуголь», угольная компания
# DONE 220 «КуйбышевАзот»
# DONE 221 «КуйбышевАзот»
# DONE 222 «КуйбышевАзот»
# DONE 223 «КуйбышевАзот»
# DONE 224 «КуйбышевАзот»
# DONE 225 «ЛУКОЙЛ»
# DONE 226 «ЛУКОЙЛ»
# DONE 227 «ЛУКОЙЛ»
# DONE 228 «ЛУКОЙЛ»
# DONE 229 «ЛУКОЙЛ»
# Failed to download PDF: ('https://lenta.com/globalassets/docs/partners/Kodeks-delovogo-povedeniya.pdf', 433)
# DONE 230 «Лента» (сеть гипермаркетов)
# Failed to download PDF: ('https://lenta.com/globalassets/docs/investors/charter_10-05-2012.pdf', 433)
# DONE 231 «Лента» (сеть гипермаркетов)
# DONE 232 «ЛУКОЙЛ»
# DONE 233 «ЛУКОЙЛ»
# DONE 234 «ЛУКОЙЛ»
# DONE 235 «Лента» (сеть гипермаркетов)
# DONE 236 «Лента» (сеть гипермаркетов)
# DONE 237 «Лента» (сеть гипермаркетов)
# DONE 238 «Лента» (сеть гипермаркетов)
# DONE 239 «Лента» (сеть гипермаркетов)
# Failed to download PDF: ('https://lenta.com/globalassets/docs/partners/Politika-po-protivodeystviyu-korruptsii.pdf', 433)
# DONE 240 «Лента» (сеть гипермаркетов)
# DONE 241 «Лента» (сеть гипермаркетов)
# DONE 242 «Лента» (сеть гипермаркетов)
# DONE 243 «М.Видео-Эльдорадо», группа
# DONE 244 «М.Видео-Эльдорадо», группа
# DONE 245 «М.Видео-Эльдорадо», группа
# DONE 246 «М.Видео-Эльдорадо», группа
# DONE 247 «М.Видео-Эльдорадо», группа
# DONE 248 «М.Видео-Эльдорадо», группа
# DONE 249 «М.Видео-Эльдорадо», группа
# DONE 250 «МОСКОВСКИЙ КРЕДИТНЫЙ БАНК»
# DONE 251 «М.Видео-Эльдорадо», группа
# DONE 252 «МОСКОВСКИЙ КРЕДИТНЫЙ БАНК»
# DONE 253 «МОСКОВСКИЙ КРЕДИТНЫЙ БАНК»
# DONE 254 «М.Видео-Эльдорадо», группа
# ERROR 255 Омск Карбон Групп Message: invalid argument
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x58b4529c6e9a <unknown>
# #1 0x58b4526b02a1 <unknown>
# #2 0x58b452696973 <unknown>
# #3 0x58b4526951b8 <unknown>
# #4 0x58b45269583a <unknown>
# #5 0x58b4526b2ea7 <unknown>
# #6 0x58b45273eed5 <unknown>
# #7 0x58b45271f4b2 <unknown>
# #8 0x58b45273e2cc <unknown>
# #9 0x58b45271f253 <unknown>
# #10 0x58b4526ef1c7 <unknown>
# #11 0x58b4526efb3e <unknown>
# #12 0x58b45298d2db <unknown>
# #13 0x58b452991387 <unknown>
# #14 0x58b452979e0e <unknown>
# #15 0x58b452991e52 <unknown>
# #16 0x58b45295e7af <unknown>
# #17 0x58b4529b6188 <unknown>
# #18 0x58b4529b635b <unknown>
# #19 0x58b4529c5fcc <unknown>
# #20 0x78d594fefac3 <unknown>
#
# DONE 256 «Магнит», розничная сеть
# DONE 257 «Магнит», розничная сеть
# DONE 258 «Магнит», розничная сеть
# ERROR 259 «Магнит», розничная сеть Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5c95e9e2ce9a <unknown>
# #1 0x5c95e9b1645c <unknown>
# #2 0x5c95e9b0dfd0 <unknown>
# #3 0x5c95e9afdb32 <unknown>
# #4 0x5c95e9aff162 <unknown>
# #5 0x5c95e9afdded <unknown>
# #6 0x5c95e9afd503 <unknown>
# #7 0x5c95e9afd3f5 <unknown>
# #8 0x5c95e9afb336 <unknown>
# #9 0x5c95e9afb83a <unknown>
# #10 0x5c95e9b18ea7 <unknown>
# #11 0x5c95e9ba4ed5 <unknown>
# #12 0x5c95e9b854b2 <unknown>
# #13 0x5c95e9ba42cc <unknown>
# #14 0x5c95e9b85253 <unknown>
# #15 0x5c95e9b551c7 <unknown>
# #16 0x5c95e9b55b3e <unknown>
# #17 0x5c95e9df32db <unknown>
# #18 0x5c95e9df7387 <unknown>
# #19 0x5c95e9ddfe0e <unknown>
# #20 0x5c95e9df7e52 <unknown>
# #21 0x5c95e9dc47af <unknown>
# #22 0x5c95e9e1c188 <unknown>
# #23 0x5c95e9e1c35b <unknown>
# #24 0x5c95e9e2bfcc <unknown>
# #25 0x78955ebb1ac3 <unknown>
#
# DONE 260 «Магнит», розничная сеть
# DONE 261 «Магнит», розничная сеть
# DONE 262 «Магнит», розничная сеть
# DONE 263 «Магнит», розничная сеть
# DONE 264 «Магнит», розничная сеть
# DONE 265 «Магнит», розничная сеть
# ERROR 266 «МегаФон» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5c763e5f9e9a <unknown>
# #1 0x5c763e2e345c <unknown>
# #2 0x5c763e2dafd0 <unknown>
# #3 0x5c763e2cab32 <unknown>
# #4 0x5c763e2cc162 <unknown>
# #5 0x5c763e2caded <unknown>
# #6 0x5c763e2ca503 <unknown>
# #7 0x5c763e2ca3f5 <unknown>
# #8 0x5c763e2c8336 <unknown>
# #9 0x5c763e2c883a <unknown>
# #10 0x5c763e2e5ea7 <unknown>
# #11 0x5c763e371ed5 <unknown>
# #12 0x5c763e3524b2 <unknown>
# #13 0x5c763e3712cc <unknown>
# #14 0x5c763e352253 <unknown>
# #15 0x5c763e3221c7 <unknown>
# #16 0x5c763e322b3e <unknown>
# #17 0x5c763e5c02db <unknown>
# #18 0x5c763e5c4387 <unknown>
# #19 0x5c763e5ace0e <unknown>
# #20 0x5c763e5c4e52 <unknown>
# #21 0x5c763e5917af <unknown>
# #22 0x5c763e5e9188 <unknown>
# #23 0x5c763e5e935b <unknown>
# #24 0x5c763e5f8fcc <unknown>
# #25 0x7accc284dac3 <unknown>
#
# ERROR 267 «МегаФон» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5caee8785e9a <unknown>
# #1 0x5caee846f45c <unknown>
# #2 0x5caee8466fd0 <unknown>
# #3 0x5caee8456b32 <unknown>
# #4 0x5caee8458162 <unknown>
# #5 0x5caee8456ded <unknown>
# #6 0x5caee8456503 <unknown>
# #7 0x5caee84563f5 <unknown>
# #8 0x5caee8454336 <unknown>
# #9 0x5caee845483a <unknown>
# #10 0x5caee8471ea7 <unknown>
# #11 0x5caee84fded5 <unknown>
# #12 0x5caee84de4b2 <unknown>
# #13 0x5caee84fd2cc <unknown>
# #14 0x5caee84de253 <unknown>
# #15 0x5caee84ae1c7 <unknown>
# #16 0x5caee84aeb3e <unknown>
# #17 0x5caee874c2db <unknown>
# #18 0x5caee8750387 <unknown>
# #19 0x5caee8738e0e <unknown>
# #20 0x5caee8750e52 <unknown>
# #21 0x5caee871d7af <unknown>
# #22 0x5caee8775188 <unknown>
# #23 0x5caee877535b <unknown>
# #24 0x5caee8784fcc <unknown>
# #25 0x7a14a0d88ac3 <unknown>
#
# ERROR 268 «МегаФон» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5833bd45ae9a <unknown>
# #1 0x5833bd14445c <unknown>
# #2 0x5833bd13bfd0 <unknown>
# #3 0x5833bd12bb32 <unknown>
# #4 0x5833bd12d162 <unknown>
# #5 0x5833bd12bded <unknown>
# #6 0x5833bd12b503 <unknown>
# #7 0x5833bd12b3f5 <unknown>
# #8 0x5833bd129336 <unknown>
# #9 0x5833bd12983a <unknown>
# #10 0x5833bd146ea7 <unknown>
# #11 0x5833bd1d2ed5 <unknown>
# #12 0x5833bd1b34b2 <unknown>
# #13 0x5833bd1d22cc <unknown>
# #14 0x5833bd1b3253 <unknown>
# #15 0x5833bd1831c7 <unknown>
# #16 0x5833bd183b3e <unknown>
# #17 0x5833bd4212db <unknown>
# #18 0x5833bd425387 <unknown>
# #19 0x5833bd40de0e <unknown>
# #20 0x5833bd425e52 <unknown>
# #21 0x5833bd3f27af <unknown>
# #22 0x5833bd44a188 <unknown>
# #23 0x5833bd44a35b <unknown>
# #24 0x5833bd459fcc <unknown>
# #25 0x7fc3574a7ac3 <unknown>
#
# ERROR 269 «МегаФон» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0
# DONE 315 «Новороссийский морской торговый порт»
# DONE 316 «Новороссийский морской торговый порт»
# DONE 317 «Новороссийский морской торговый порт»
# DONE 318 «Новороссийский морской торговый порт»
# DONE 319 «Норильский никель», горно-металлургическая компания
# DONE 320 «Норильский никель», горно-металлургическая компания
# DONE 321 «Норильский никель», горно-металлургическая компания
# DONE 322 «Норильский никель», горно-металлургическая компания
# DONE 323 «Норильский никель», горно-металлургическая компания
# DONE 324 «Норильский никель», горно-металлургическая компания
# Failed to download PDF: ('https://www.nornickel.ru/upload/iblock/1cd/Norilsk_Nickel_Environmental_Strategy_2021_ru.pdf', 403)
# DONE 325 «Норильский никель», горно-металлургическая компания
# DONE 326 «Норильский никель», горно-металлургическая компания
# DONE 327 «Норильский никель», горно-металлургическая компания
# DONE 328 «О'КЕЙ»
# DONE 329 «О'КЕЙ»
# DONE 330 «О'КЕЙ»
# DONE 331 «О'КЕЙ»
# DONE 332 «О'КЕЙ»
# DONE 333 «Объединенная авиастроительная корпорация»
# DONE 334 «Объединенная авиастроительная корпорация»
# ERROR 335 «Объединенная судостроительная корпорация» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x58b5f36a7e9a <unknown>
# #1 0x58b5f339145c <unknown>
# #2 0x58b5f3388fd0 <unknown>
# #3 0x58b5f3378b32 <unknown>
# #4 0x58b5f337a162 <unknown>
# #5 0x58b5f3378ded <unknown>
# #6 0x58b5f3378503 <unknown>
# #7 0x58b5f33783f5 <unknown>
# #8 0x58b5f3376336 <unknown>
# #9 0x58b5f337683a <unknown>
# #10 0x58b5f3393ea7 <unknown>
# #11 0x58b5f341fed5 <unknown>
# #12 0x58b5f34004b2 <unknown>
# #13 0x58b5f341f2cc <unknown>
# #14 0x58b5f3400253 <unknown>
# #15 0x58b5f33d01c7 <unknown>
# #16 0x58b5f33d0b3e <unknown>
# #17 0x58b5f366e2db <unknown>
# #18 0x58b5f3672387 <unknown>
# #19 0x58b5f365ae0e <unknown>
# #20 0x58b5f3672e52 <unknown>
# #21 0x58b5f363f7af <unknown>
# #22 0x58b5f3697188 <unknown>
# #23 0x58b5f369735b <unknown>
# #24 0x58b5f36a6fcc <unknown>
# #25 0x7d4e4040fac3 <unknown>
#
# DONE 336 «Объединенная авиастроительная корпорация»
# DONE 337 «Объединенная авиастроительная корпорация»
# DONE 338 «Объединенная авиастроительная корпорация»
# ERROR 339 «Объединенная судостроительная корпорация» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x56f831f14e9a <unknown>
# #1 0x56f831bfe45c <unknown>
# #2 0x56f831bf5fd0 <unknown>
# #3 0x56f831be5b32 <unknown>
# #4 0x56f831be7162 <unknown>
# #5 0x56f831be5ded <unknown>
# #6 0x56f831be5503 <unknown>
# #7 0x56f831be53f5 <unknown>
# #8 0x56f831be3336 <unknown>
# #9 0x56f831be383a <unknown>
# #10 0x56f831c00ea7 <unknown>
# #11 0x56f831c8ced5 <unknown>
# #12 0x56f831c6d4b2 <unknown>
# #13 0x56f831c8c2cc <unknown>
# #14 0x56f831c6d253 <unknown>
# #15 0x56f831c3d1c7 <unknown>
# #16 0x56f831c3db3e <unknown>
Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5c859f844e9a <unknown>
# #1 0x5c859f52e45c <unknown>
# #2 0x5c859f525fd0 <unknown>
# #3 0x5c859f515b32 <unknown>
# #4 0x5c859f517162 <unknown>
# #5 0x5c859f515ded <unknown>
# #6 0x5c859f515503 <unknown>
# #7 0x5c859f5153f5 <unknown>
# #8 0x5c859f513336 <unknown>
# #9 0x5c859f51383a <unknown>
# #10 0x5c859f530ea7 <unknown>
# #11 0x5c859f5bced5 <unknown>
# #12 0x5c859f59d4b2 <unknown>
# #13 0x5c859f5bc2cc <unknown>
# #14 0x5c859f59d253 <unknown>
# #15 0x5c859f56d1c7 <unknown>
# #16 0x5c859f56db3e <unknown>
# #17 0x5c859f80b2db <unknown>
# #18 0x5c859f80f387 <unknown>
# #19 0x5c859f7f7e0e <unknown>
# #20 0x5c859f80fe52 <unknown>
# #21 0x5c859f7dc7af <unknown>
# #22 0x5c859f834188 <unknown>
# #23 0x5c859f83435b <unknown>
# #24 0x5c859f843fcc <unknown>
# #25 0x7a4d37160ac3 <unknown>
#
# DONE 380 «Ростелеком»
# DONE 381 «Ростелеком»
# DONE 382 «Ростелеком»
# DONE 383 «Ростелеком»
# DONE 384 «Ростелеком»
# DONE 385 «Ростелеком»
# DONE 386 «РусГидро»
# DONE 387 «РусГидро»
# DONE 388 «РусГидро»
# ERROR 389 «РусГидро» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5b4fb8ee3e9a <unknown>
# #1 0x5b4fb8bcd45c <unknown>
# #2 0x5b4fb8bc4fd0 <unknown>
# #3 0x5b4fb8bb4b32 <unknown>
# #4 0x5b4fb8bb6162 <unknown>
# #5 0x5b4fb8bb4ded <unknown>
# #6 0x5b4fb8bb4503 <unknown>
# #7 0x5b4fb8bb43f5 <unknown>
# #8 0x5b4fb8bb2336 <unknown>
# #9 0x5b4fb8bb283a <unknown>
# #10 0x5b4fb8bcfea7 <unknown>
# #11 0x5b4fb8c5bed5 <unknown>
# #12 0x5b4fb8c3c4b2 <unknown>
# #13 0x5b4fb8c5b2cc <unknown>
# #14 0x5b4fb8c3c253 <unknown>
# #15 0x5b4fb8c0c1c7 <unknown>
# #16 0x5b4fb8c0cb3e <unknown>
# #17 0x5b4fb8eaa2db <unknown>
# #18 0x5b4fb8eae387 <unknown>
# #19 0x5b4fb8e96e0e <unknown>
# #20 0x5b4fb8eaee52 <unknown>
# #21 0x5b4fb8e7b7af <unknown>
# #22 0x5b4fb8ed3188 <unknown>
# #23 0x5b4fb8ed335b <unknown>
# #24 0x5b4fb8ee2fcc <unknown>
# #25 0x7f5c53d3aac3 <unknown>
#
# DONE 390 «РусГидро»
# DONE 391 «РусГидро»
# DONE 392 «РусГидро»
# DONE 393 «РусГидро»
# DONE 394 «РусГидро»
# DONE 395 «Русагро», группа компаний
# DONE 396 «Русагро», группа компаний
# DONE 397 «Русагро», группа компаний
# DONE 398 «Русагро», группа компаний
# DONE 399 «Русагро», группа компаний
# DONE 400 «Русал», объединенная компания
# DONE 401 «Русал», объединенная компания
# DONE 402 «Русал», объединенная компания
# DONE 403 «Русал», объединенная компания
# DONE 404 «Русал», объединенная компания
# DONE 405 «Русал», объединенная компания
# DONE 406 «РуссНефть», нефтегазовая компания
# DONE 407 «РуссНефть», нефтегазовая компания
# DONE 408 «Русал», объединенная компания
# DONE 409 «Сургутнефтегаз»
# DONE 410 «РуссНефть», нефтегазовая компания
# DONE 411 «РуссНефть», нефтегазовая компания
# DONE 412 «РуссНефть», нефтегазовая компания
# DONE 413 «Русский уголь»
# DONE 414 «Русская медная компания»
# DONE 415 «Русский уголь»
# DONE 416 «Русский уголь»
# DONE 417 «Русский уголь»
# DONE 418 «СИБУР Холдинг»
# DONE 419 «СИБУР Холдинг»
# DONE 420 «СИБУР Холдинг»
# DONE 421 «СИБУР Холдинг»
# DONE 422 «СИБУР Холдинг»
# DONE 423 «СИБУР Холдинг»
# DONE 424 «СИБУР Холдинг»
# DONE 425 «Сахалинская энергия»
# DONE 426 «СИБУР Холдинг»
# DONE 427 «СИБУР Холдинг»
# DONE 428 «СИБУР Холдинг»
# DONE 429 «Сахалинская энергия»
# DONE 430 «Сахалинская энергия»
# DONE 431 «Сахалинская энергия»
# DONE 432 «Сахалинская энергия»
# DONE 433 «Северсталь»
# DONE 434 «Северсталь»
# DONE 435 «Северсталь»
# DONE 436 «Северсталь»
# DONE 437 «Северсталь»
# DONE 438 «Северсталь»
# DONE 439 «Северсталь»
# DONE 440 «Сибантрацит», группа
# DONE 441 «Сибантрацит», группа
# DONE 442 «Сибантрацит», группа
# DONE 443 «Северсталь»
# DONE 444 «Сибантрацит», группа
# DONE 445 «Славнефть», группа
# DONE 446 «Славнефть», группа
# DONE 447 «Славнефть», группа
# DONE 448 «Славнефть», группа
# DONE 449 «Славнефть», группа
# DONE 450 «Совкомфлот»
# DONE 451 «Совкомфлот»
# DONE 452 «Совкомфлот»
# DONE 453 «Совкомфлот»
# DONE 454 «Совкомфлот»
# DONE 455 «Совкомфлот»
# DONE 456 «Стройсервис»
# DONE 457 «Стройсервис»
# DONE 458 «Стройсервис»
# DONE 459 «Стройсервис»
# DONE 460 «Сургутнефтегаз»
# DONE 461 «Сургутнефтегаз»
# DONE 462 «Сургутнефтегаз»
# DONE 463 «Сургутнефтегаз»
# ERROR 464 «Т Плюс» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x577dc0f02e9a <unknown>
# #1 0x577dc0bec45c <unknown>
# #2 0x577dc0be3fd0 <unknown>
# #3 0x577dc0bd3b32 <unknown>
# #4 0x577dc0bd5162 <unknown>
# #5 0x577dc0bd3ded <unknown>
# #6 0x577dc0bd3503 <unknown>
# #7 0x577dc0bd33f5 <unknown>
# #8 0x577dc0bd1336 <unknown>
# #9 0x577dc0bd183a <unknown>
# #10 0x577dc0beeea7 <unknown>
# #11 0x577dc0c7aed5 <unknown>
# #12 0x577dc0c5b4b2 <unknown>
# #13 0x577dc0c7a2cc <unknown>
# #14 0x577dc0c5b253 <unknown>
# #15 0x577dc0c2b1c7 <unknown>
# #16 0x577dc0c2bb3e <unknown>
# #17 0x577dc0ec92db <unknown>
# #18 0x577dc0ecd387 <unknown>
# #19 0x577dc0eb5e0e <unknown>
# #20 0x577dc0ecde52 <unknown>
# #21 0x577dc0e9a7af <unknown>
# #22 0x577dc0ef2188 <unknown>
# #23 0x577dc0ef235b <unknown>
# #24 0x577dc0f01fcc <unknown>
# #25 0x799ab916aac3 <unknown>
#
# ERROR 465 «Т Плюс» Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0
# #20 0x5b6acfad9e52 <unknown>
# #21 0x5b6acfaa67af <unknown>
# #22 0x5b6acfafe188 <unknown>
# #23 0x5b6acfafe35b <unknown>
# #24 0x5b6acfb0dfcc <unknown>
# #25 0x7b4a88b4fac3 <unknown>
#
# DONE 660 Магнитогорский металлургический комбинат (ММК)
# DONE 661 Магнитогорский металлургический комбинат (ММК)
# DONE 662 Магнитогорский металлургический комбинат (ММК)
# DONE 663 Магнитогорский металлургический комбинат (ММК)
# DONE 664 Магнитогорский металлургический комбинат (ММК)
# DONE 665 Московская Биржа
# DONE 666 Московская Биржа
# DONE 667 Московская Биржа
# DONE 668 Московская Биржа
# DONE 669 Московская Биржа
# DONE 670 НЛМК
# DONE 671 НЛМК
# DONE 672 НЛМК
# DONE 673 НЛМК
# DONE 674 НЛМК
# DONE 675 НЛМК
# DONE 676 НЛМК
# ERROR 677 НОВАТЭК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x57ddb1672e9a <unknown>
# #1 0x57ddb135c45c <unknown>
# #2 0x57ddb1353fd0 <unknown>
# #3 0x57ddb1343b32 <unknown>
# #4 0x57ddb1345162 <unknown>
# #5 0x57ddb1343ded <unknown>
# #6 0x57ddb1343503 <unknown>
# #7 0x57ddb13433f5 <unknown>
# #8 0x57ddb1341336 <unknown>
# #9 0x57ddb134183a <unknown>
# #10 0x57ddb135eea7 <unknown>
# #11 0x57ddb13eaed5 <unknown>
# #12 0x57ddb13cb4b2 <unknown>
# #13 0x57ddb13ea2cc <unknown>
# #14 0x57ddb13cb253 <unknown>
# #15 0x57ddb139b1c7 <unknown>
# #16 0x57ddb139bb3e <unknown>
# #17 0x57ddb16392db <unknown>
# #18 0x57ddb163d387 <unknown>
# #19 0x57ddb1625e0e <unknown>
# #20 0x57ddb163de52 <unknown>
# #21 0x57ddb160a7af <unknown>
# #22 0x57ddb1662188 <unknown>
# #23 0x57ddb166235b <unknown>
# #24 0x57ddb1671fcc <unknown>
# #25 0x7e512b031ac3 <unknown>
#
# ERROR 678 НОВАТЭК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x58dcb5202e9a <unknown>
# #1 0x58dcb4eec45c <unknown>
# #2 0x58dcb4ee3fd0 <unknown>
# #3 0x58dcb4ed3b32 <unknown>
# #4 0x58dcb4ed5162 <unknown>
# #5 0x58dcb4ed3ded <unknown>
# #6 0x58dcb4ed3503 <unknown>
# #7 0x58dcb4ed33f5 <unknown>
# #8 0x58dcb4ed1336 <unknown>
# #9 0x58dcb4ed183a <unknown>
# #10 0x58dcb4eeeea7 <unknown>
# #11 0x58dcb4f7aed5 <unknown>
# #12 0x58dcb4f5b4b2 <unknown>
# #13 0x58dcb4f7a2cc <unknown>
# #14 0x58dcb4f5b253 <unknown>
# #15 0x58dcb4f2b1c7 <unknown>
# #16 0x58dcb4f2bb3e <unknown>
# #17 0x58dcb51c92db <unknown>
# #18 0x58dcb51cd387 <unknown>
# #19 0x58dcb51b5e0e <unknown>
# #20 0x58dcb51cde52 <unknown>
# #21 0x58dcb519a7af <unknown>
# #22 0x58dcb51f2188 <unknown>
# #23 0x58dcb51f235b <unknown>
# #24 0x58dcb5201fcc <unknown>
# #25 0x789780748ac3 <unknown>
#
# ERROR 679 НОВАТЭК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5aadfa625e9a <unknown>
# #1 0x5aadfa30f45c <unknown>
# #2 0x5aadfa306fd0 <unknown>
# #3 0x5aadfa2f6b32 <unknown>
# #4 0x5aadfa2f8162 <unknown>
# #5 0x5aadfa2f6ded <unknown>
# #6 0x5aadfa2f6503 <unknown>
# #7 0x5aadfa2f63f5 <unknown>
# #8 0x5aadfa2f4336 <unknown>
# #9 0x5aadfa2f483a <unknown>
# #10 0x5aadfa311ea7 <unknown>
# #11 0x5aadfa39ded5 <unknown>
# #12 0x5aadfa37e4b2 <unknown>
# #13 0x5aadfa39d2cc <unknown>
# #14 0x5aadfa37e253 <unknown>
# #15 0x5aadfa34e1c7 <unknown>
# #16 0x5aadfa34eb3e <unknown>
# #17 0x5aadfa5ec2db <unknown>
# #18 0x5aadfa5f0387 <unknown>
# #19 0x5aadfa5d8e0e <unknown>
# #20 0x5aadfa5f0e52 <unknown>
# #21 0x5aadfa5bd7af <unknown>
# #22 0x5aadfa615188 <unknown>
# #23 0x5aadfa61535b <unknown>
# #24 0x5aadfa624fcc <unknown>
# #25 0x7e0697d17ac3 <unknown>
#
# DONE 680 Новикомбанк
# DONE 681 Новикомбанк
# DONE 682 Новикомбанк
# ERROR 683 НОВАТЭК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x56d69f810e9a <unknown>
# #1 0x56d69f4fa45c <unknown>
# #2 0x56d69f4f1fd0 <unknown>
# #3 0x56d69f4e1b32 <unknown>
# #4 0x56d69f4e3162 <unknown>
# #5 0x56d69f4e1ded <unknown>
# #6 0x56d69f4e1503 <unknown>
# #7 0x56d69f4e13f5 <unknown>
# #8 0x56d69f4df336 <unknown>
# #9 0x56d69f4df83a <unknown>
# #10 0x56d69f4fcea7 <unknown>
# #11 0x56d69f588ed5 <unknown>
# #12 0x56d69f5694b2 <unknown>
# #13 0x56d69f5882cc <unknown>
# #14 0x56d69f569253 <unknown>
# #15 0x56d69f5391c7 <unknown>
# #16 0x56d69f539b3e <unknown>
# #17 0x56d69f7d72db <unknown>
# #18 0x56d69f7db387 <unknown>
# #19 0x56d69f7c3e0e <unknown>
# #20 0x56d69f7dbe52 <unknown>
# #21 0x56d69f7a87af <unknown>
# #22 0x56d69f800188 <unknown>
# #23 0x56d69f80035b <unknown>
# #24 0x56d69f80ffcc <unknown>
# #25 0x7f2097690ac3 <unknown>
#
# ERROR 684 НОВАТЭК Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5814b83abe9a <unknown>
# #1 0x5814b809545c <unknown>
# #2 0x5814b808cfd0 <unknown>
# #3 0x5814b807cb32 <unknown>
# #4 0x5814b807e162 <unknown>
# #5 0x5814b807cded <unknown>
# #6 0x5814b807c503 <unknown>
# #7 0x5814b807c3f5 <unknown>
# #8 0x5814b807a336 <unknown>
# #9 0x5814b807a83a <unknown>
# #10 0x5814b8097ea7 <unknown>
# #11 0x5814b8123ed5 <unknown>
# #12 0x5814b81044b2 <unknown>
# #13 0x5814b81232cc <unknown>
# #14 0x5814b8104253 <unknown>
# #15 0x5814b80d41c7 <unknown>
# #16 0x5814b80d4b3e <unknown>
# #17 0x5814b83722db <unknown>
# #18 0x5814b8376387 <unknown>
# #19 0x5814b835ee0e <unknown>
# #20 0x5814b8376e52 <unknown>
# #21 0x5814b83437af <unknown>
# #22 0x5814b839b188 <unknown>
# #23 0x5814b839b35b <unknown>
# #24 0x5814b83aafcc <unknown>
# #25 0x7fdb1198fac3 <unknown>
#
# DONE 685 ОГК Групп
# DONE 686 Объединенная металлургическая компания (ОМК)
# DONE 687 Новикомбанк
# DONE 688 Новикомбанк
# DONE 689 Объединенная металлургическая компания (ОМК)
# DONE 690 Омск Карбон Групп
# DONE 691 Омск Карбон Групп
# DONE 692 Объединенная металлургическая компания (ОМК)
# DONE 693 Объединенная металлургическая компания (ОМК)
# DONE 694 ПАО "МТС"
# DONE 695 ПАО "МТС"
# DONE 696 ПАО «Селигдар»
# DONE 697 ПАО «Селигдар»
# DONE 698 ПАО "МТС"
# DONE 699 ПАО "МТС"
# DONE 700 ПАО «Селигдар»
# DONE 701 ПАО «Селигдар»
# DONE 702 ПАО «Селигдар»
# DONE 703 ПАО «Селигдар»
# DONE 704 ПАО «Селигдар»
# DONE 705 Пигмент (КРАТА)
# DONE 706 Пигмент (КРАТА)
# DONE 707 ПАО КБ «‎Центр-Инвест»
# DONE 708 ПАО КБ «‎Центр-Инвест»
# DONE 709 Пигмент (КРАТА)
# DONE 710 Пигмент (КРАТА)
# DONE 711 Пигмент (КРАТА)
# DONE 712 Пигмент (КРАТА)
# DONE 713 Пигмент (КРАТА)
# DONE 714 Пигмент (КРАТА)
# DONE 715 Прииск Соловьевский
# DONE 716 Прииск Соловьевский
# DONE 717 Прииск Соловьевский
# ERROR 718 Промсвязьбанк Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0x5d0d08817e9a <unknown>
# #1 0x5d0d0850145c <unknown>
# #2 0x5d0d084f8fd0 <unknown>
# #3 0x5d0d084e8b32 <unknown>
# #4 0x5d0d084ea162 <unknown>
# #5 0x5d0d084e8ded <unknown>
# #6 0x5d0d084e8503 <unknown>
# #7 0x5d0d084e83f5 <unknown>
# #8 0x5d0d084e6336 <unknown>
# #9 0x5d0d084e683a <unknown>
# #10 0x5d0d08503ea7 <unknown>
# #11 0x5d0d0858fed5 <unknown>
# #12 0x5d0d085704b2 <unknown>
# #13 0x5d0d0858f2cc <unknown>
# #14 0x5d0d08570253 <unknown>
# #15 0x5d0d085401c7 <unknown>
# #16 0x5d0d08540b3e <unknown>
# #17 0x5d0d087de2db <unknown>
# #18 0x5d0d087e2387 <unknown>
# #19 0x5d0d087cae0e <unknown>
# #20 0x5d0d087e2e52 <unknown>
# #21 0x5d0d087af7af <unknown>
# #22 0x5d0d08807188 <unknown>
# #23 0x5d0d0880735b <unknown>
# #24 0x5d0d08816fcc <unknown>
# #25 0x7b809e68aac3 <unknown>
#
# ERROR 719 Промсвязьбанк Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: chrome-headless-shell=125.0.6422.76)
# Stacktrace:
# #0 0
Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 812 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 813 Юникредит Банк
# DONE 814 Юникредит Банк
# DONE 815 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 816 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 817 Якутская топливно-энергетическая компания (ЯТЭК)
# Links are collected!
# CPU times: user 1min 41s, sys: 5.99 s, total: 1min 47s
# Wall time: 1h 28min 54s

# %%
folder_path = 'PDFs'
output_path = 'PDFs.zip'

zip_folder(folder_path, output_path)

# %%
links = pd.read_csv('links.csv', index_col=0)

with zipfile.ZipFile('PDFs.zip', 'r') as zipf:
    zipf.extractall('PDFs')

print(len(links.company.unique()))

urls = links.set_index('urls')['company'].to_dict()
print(len(urls))
# Out:
# 143
# 9399

# %%
# %%time
chunk_size = 4
parsed_data = pd.DataFrame()
i = 0
for URLs_chunk in chunkify(urls, chunk_size):
    chunk_results, i = process_chunk(URLs_chunk, i, parsing)
    try:
        parsed_data = pd.concat([parsed_data, chunk_results])
        del chunk_results
        gc.collect()
    except Exception as err:
        continue

print("Parcing is finished!")

parsed_data = parsed_data.drop_duplicates()
parsed_data = parsed_data.reset_index(drop=True)
parsed_data.to_csv('parsed_data_train.csv', encoding='utf-8')
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# #3 0x5a09817083f5 <unknown>
# #4 0x5a0981706336 <unknown>
# #5 0x5a09817069af <unknown>
# #6 0x5a0981717287 <unknown>
# #7 0x5a098172d55e <unknown>
# #8 0x5a0981732c5b <unknown>
# #9 0x5a09817070fa <unknown>
# #10 0x5a098172d14f <unknown>
# #11 0x5a09817af195 <unknown>
# #12 0x5a0981790253 <unknown>
# #13 0x5a09817601c7 <unknown>
# #14 0x5a0981760b3e <unknown>
# #15 0x5a09819fe2cb <unknown>
# #16 0x5a0981a02377 <unknown>
# #17 0x5a09819eadfe <unknown>
# #18 0x5a0981a02e42 <unknown>
# #19 0x5a09819cf79f <unknown>
# #20 0x5a0981a27178 <unknown>
# #21 0x5a0981a2734b <unknown>
# #22 0x5a0981a36fbc <unknown>
# #23 0x7bab57d41ac3 <unknown>
#
# ERROR 7730 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.010
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x598ee4defe8a <unknown>
# #1 0x598ee4ad945c <unknown>
# #2 0x598ee4ac0816 <unknown>
# #3 0x598ee4ac03f5 <unknown>
# #4 0x598ee4abe336 <unknown>
# #5 0x598ee4abe9af <unknown>
# #6 0x598ee4acf287 <unknown>
# #7 0x598ee4ae555e <unknown>
# #8 0x598ee4aeac5b <unknown>
# #9 0x598ee4abf0fa <unknown>
# #10 0x598ee4ae514f <unknown>
# #11 0x598ee4b67195 <unknown>
# #12 0x598ee4b48253 <unknown>
# #13 0x598ee4b181c7 <unknown>
# #14 0x598ee4b18b3e <unknown>
# #15 0x598ee4db62cb <unknown>
# #16 0x598ee4dba377 <unknown>
# #17 0x598ee4da2dfe <unknown>
# #18 0x598ee4dbae42 <unknown>
# #19 0x598ee4d8779f <unknown>
# #20 0x598ee4ddf178 <unknown>
# #21 0x598ee4ddf34b <unknown>
# #22 0x598ee4deefbc <unknown>
# #23 0x7ecc9317eac3 <unknown>
#
# ERROR 7731 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.009
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0
Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x573a9364ae8a <unknown>
# #1 0x573a9333445c <unknown>
# #2 0x573a9331b816 <unknown>
# #3 0x573a9331b3f5 <unknown>
# #4 0x573a93319336 <unknown>
# #5 0x573a933199af <unknown>
# #6 0x573a9332a287 <unknown>
# #7 0x573a9334055e <unknown>
# #8 0x573a93345c5b <unknown>
# #9 0x573a9331a0fa <unknown>
# #10 0x573a933402cf <unknown>
# #11 0x573a933c2195 <unknown>
# #12 0x573a933a3253 <unknown>
# #13 0x573a933731c7 <unknown>
# #14 0x573a93373b3e <unknown>
# #15 0x573a936112cb <unknown>
# #16 0x573a93615377 <unknown>
# #17 0x573a935fddfe <unknown>
# #18 0x573a93615e42 <unknown>
# #19 0x573a935e279f <unknown>
# #20 0x573a9363a178 <unknown>
# #21 0x573a9363a34b <unknown>
# #22 0x573a93649fbc <unknown>
# #23 0x7edb34503ac3 <unknown>
#
# ERROR 7735 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.026
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x58e41fbe9e8a <unknown>
# #1 0x58e41f8d345c <unknown>
# #2 0x58e41f8ba816 <unknown>
# #3 0x58e41f8ba3f5 <unknown>
# #4 0x58e41f8b8336 <unknown>
# #5 0x58e41f8b89af <unknown>
# #6 0x58e41f8c9287 <unknown>
# #7 0x58e41f8df55e <unknown>
# #8 0x58e41f8e4c5b <unknown>
# #9 0x58e41f8b90fa <unknown>
# #10 0x58e41f8df14f <unknown>
# #11 0x58e41f961195 <unknown>
# #12 0x58e41f942253 <unknown>
# #13 0x58e41f9121c7 <unknown>
# #14 0x58e41f912b3e <unknown>
# #15 0x58e41fbb02cb <unknown>
# #16 0x58e41fbb4377 <unknown>
# #17 0x58e41fb9cdfe <unknown>
# #18 0x58e41fbb4e42 <unknown>
# #19 0x58e41fb8179f <unknown>
# #20 0x58e41fbd9178 <unknown>
# #21 0x58e41fbd934b <unknown>
# #22 0x58e41fbe8fbc <unknown>
# #23 0x78c823887ac3 <unknown>
#
# ERROR 7736 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.015
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5ad8cd7e7e8a <unknown>
# #1 0x5ad8cd4d145c <unknown>
# #2 0x5ad8cd4b8816 <unknown>
# #3 0x5ad8cd4b83f5 <unknown>
# #4 0x5ad8cd4b6336 <unknown>
# #5 0x5ad8cd4b69af <unknown>
# #6 0x5ad8cd4c7287 <unknown>
# #7 0x5ad8cd4dd55e <unknown>
# #8 0x5ad8cd4e2c5b <unknown>
# #9 0x5ad8cd4b70fa <unknown>
# #10 0x5ad8cd4dd2cf <unknown>
# #11 0x5ad8cd55f195 <unknown>
# #12 0x5ad8cd540253 <unknown>
# #13 0x5ad8cd5101c7 <unknown>
# #14 0x5ad8cd510b3e <unknown>
# #15 0x5ad8cd7ae2cb <unknown>
# #16 0x5ad8cd7b2377 <unknown>
# #17 0x5ad8cd79adfe <unknown>
# #18 0x5ad8cd7b2e42 <unknown>
# #19 0x5ad8cd77f79f <unknown>
# #20 0x5ad8cd7d7178 <unknown>
# #21 0x5ad8cd7d734b <unknown>
# #22 0x5ad8cd7e6fbc <unknown>
# #23 0x7ca8238f2ac3 <unknown>
#
# ERROR 7737 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.008
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5b566ea72e8a <unknown>
# #1 0x5b566e75c45c <unknown>
# #2 0x5b566e743816 <unknown>
# #3 0x5b566e7433f5 <unknown>
# #4 0x5b566e741336 <unknown>
# #5 0x5b566e7419af <unknown>
# #6 0x5b566e752287 <unknown>
# #7 0x5b566e76855e <unknown>
# #8 0x5b566e76dc5b <unknown>
# #9 0x5b566e7420fa <unknown>
# #10 0x5b566e76814f <unknown>
# #11 0x5b566e7ea195 <unknown>
# #12 0x5b566e7cb253 <unknown>
# #13 0x5b566e79b1c7 <unknown>
# #14 0x5b566e79bb3e <unknown>
# #15 0x5b566ea392cb <unknown>
# #16 0x5b566ea3d377 <unknown>
# #17 0x5b566ea25dfe <unknown>
# #18 0x5b566ea3de42 <unknown>
# #19 0x5b566ea0a79f <unknown>
# #20 0x5b566ea62178 <unknown>
# #21 0x5b566ea6234b <unknown>
# #22 0x5b566ea71fbc <unknown>
# #23 0x7fe0b6cd9ac3 <unknown>
#
# ERROR 7738 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5842a15e8e8a <unknown>
# #1 0x5842a12d245c <unknown>
# #2 0x5842a12b9816 <unknown>
# #3 0x5842a12b93f5 <unknown>
# #4 0x5842a12b7336 <unknown>
# #5 0x5842a12b79af <unknown>
# #6 0x5842a12c8287 <unknown>
# #7 0x5842a12de55e <unknown>
# #8 0x5842a12e3c5b <unknown>
# #9 0x5842a12b80fa <unknown>
# #10 0x5842a12de14f <unknown>
# #11 0x5842a1360195 <unknown>
# #12 0x5842a1341253 <unknown>
# #13 0x5842a13111c7 <unknown>
# #14 0x5842a1311b3e <unknown>
# #15 0x5842a15af2cb <unknown>
# #16 0x5842a15b3377 <unknown>
# #17 0x5842a159bdfe <unknown>
# #18 0x5842a15b3e42 <unknown>
# #19 0x5842a158079f <unknown>
# #20 0x5842a15d8178 <unknown>
# #21 0x5842a15d834b <unknown>
# #22 0x5842a15e7fbc <unknown>
# #23 0x790220a80ac3 <unknown>
#
# ERROR 7739 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.012
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5aa3a749de8a <unknown>
# #1 0x5aa3a718745c <unknown>
# #2 0x5aa3a716e816 <unknown>
# #3 0x5aa3a716e3f5 <unknown>
# #4 0x5aa3a716c336 <unknown>
# #5 0x5aa3a716c9af <unknown>
# #6 0x5aa3a717d287 <unknown>
# #7 0x5aa3a719355e <unknown>
# #8 0x5aa3a7198c5b <unknown>
# #9 0x5aa3a716d0fa <unknown>
# #10 0x5aa3a71932cf <unknown>
# #11 0x5aa3a7215195 <unknown>
# #12 0x5aa3a71f6253 <unknown>
# #13 0x5aa3a71c61c7 <unknown>
# #14 0x5aa3a71c6b3e <unknown>
# #15 0x5aa3a74642cb <unknown>
# #16 0x5aa3a7468377 <unknown>
# #17 0x5aa3a7450dfe <unknown>
# #18 0x5aa3a7468e42 <unknown>
# #19 0x5aa3a743579f <unknown>
# #20 0x5aa3a748d178 <unknown>
# #21 0x5aa3a748d34b <unknown>
# #22 0x5aa3a749cfbc <unknown>
# #23 0x7e85f7998ac3 <unknown>
#
# ERROR 7740 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x
Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5783590cbe8a <unknown>
# #1 0x578358db545c <unknown>
# #2 0x578358d9c816 <unknown>
# #3 0x578358d9c3f5 <unknown>
# #4 0x578358d9a336 <unknown>
# #5 0x578358d9a9af <unknown>
# #6 0x578358dab287 <unknown>
# #7 0x578358dc155e <unknown>
# #8 0x578358dc6c5b <unknown>
# #9 0x578358d9b0fa <unknown>
# #10 0x578358dc114f <unknown>
# #11 0x578358e43195 <unknown>
# #12 0x578358e24253 <unknown>
# #13 0x578358df41c7 <unknown>
# #14 0x578358df4b3e <unknown>
# #15 0x5783590922cb <unknown>
# #16 0x578359096377 <unknown>
# #17 0x57835907edfe <unknown>
# #18 0x578359096e42 <unknown>
# #19 0x57835906379f <unknown>
# #20 0x5783590bb178 <unknown>
# #21 0x5783590bb34b <unknown>
# #22 0x5783590cafbc <unknown>
# #23 0x785b28d49ac3 <unknown>
#
# ERROR 7744 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x594737cf5e8a <unknown>
# #1 0x5947379df45c <unknown>
# #2 0x5947379c6816 <unknown>
# #3 0x5947379c63f5 <unknown>
# #4 0x5947379c4336 <unknown>
# #5 0x5947379c49af <unknown>
# #6 0x5947379d5287 <unknown>
# #7 0x5947379eb55e <unknown>
# #8 0x5947379f0c5b <unknown>
# #9 0x5947379c50fa <unknown>
# #10 0x5947379eb14f <unknown>
# #11 0x594737a6d195 <unknown>
# #12 0x594737a4e253 <unknown>
# #13 0x594737a1e1c7 <unknown>
# #14 0x594737a1eb3e <unknown>
# #15 0x594737cbc2cb <unknown>
# #16 0x594737cc0377 <unknown>
# #17 0x594737ca8dfe <unknown>
# #18 0x594737cc0e42 <unknown>
# #19 0x594737c8d79f <unknown>
# #20 0x594737ce5178 <unknown>
# #21 0x594737ce534b <unknown>
# #22 0x594737cf4fbc <unknown>
# #23 0x7c601beaeac3 <unknown>
#
# ERROR 7745 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.006
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5acda796ce8a <unknown>
# #1 0x5acda765645c <unknown>
# #2 0x5acda763d816 <unknown>
# #3 0x5acda763d3f5 <unknown>
# #4 0x5acda763b336 <unknown>
# #5 0x5acda763b9af <unknown>
# #6 0x5acda764c287 <unknown>
# #7 0x5acda766255e <unknown>
# #8 0x5acda7667c5b <unknown>
# #9 0x5acda763c0fa <unknown>
# #10 0x5acda76622cf <unknown>
# #11 0x5acda76e4195 <unknown>
# #12 0x5acda76c5253 <unknown>
# #13 0x5acda76951c7 <unknown>
# #14 0x5acda7695b3e <unknown>
# #15 0x5acda79332cb <unknown>
# #16 0x5acda7937377 <unknown>
# #17 0x5acda791fdfe <unknown>
# #18 0x5acda7937e42 <unknown>
# #19 0x5acda790479f <unknown>
# #20 0x5acda795c178 <unknown>
# #21 0x5acda795c34b <unknown>
# #22 0x5acda796bfbc <unknown>
# #23 0x7e8d6d18bac3 <unknown>
#
# ERROR 7746 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.008
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x566c067b8e8a <unknown>
# #1 0x566c064a245c <unknown>
# #2 0x566c06489816 <unknown>
# #3 0x566c064893f5 <unknown>
# #4 0x566c06487336 <unknown>
# #5 0x566c064879af <unknown>
# #6 0x566c06498287 <unknown>
# #7 0x566c064ae55e <unknown>
# #8 0x566c064b3c5b <unknown>
# #9 0x566c064880fa <unknown>
# #10 0x566c064ae14f <unknown>
# #11 0x566c06530195 <unknown>
# #12 0x566c06511253 <unknown>
# #13 0x566c064e11c7 <unknown>
# #14 0x566c064e1b3e <unknown>
# #15 0x566c0677f2cb <unknown>
# #16 0x566c06783377 <unknown>
# #17 0x566c0676bdfe <unknown>
# #18 0x566c06783e42 <unknown>
# #19 0x566c0675079f <unknown>
# #20 0x566c067a8178 <unknown>
# #21 0x566c067a834b <unknown>
# #22 0x566c067b7fbc <unknown>
# #23 0x785cb02ffac3 <unknown>
#
# ERROR 7747 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x57ad62c13e8a <unknown>
# #1 0x57ad628fd45c <unknown>
# #2 0x57ad628e4816 <unknown>
# #3 0x57ad628e43f5 <unknown>
# #4 0x57ad628e2336 <unknown>
# #5 0x57ad628e29af <unknown>
# #6 0x57ad628f3287 <unknown>
# #7 0x57ad6290955e <unknown>
# #8 0x57ad6290ec5b <unknown>
# #9 0x57ad628e30fa <unknown>
# #10 0x57ad629092cf <unknown>
# #11 0x57ad6298b195 <unknown>
# #12 0x57ad6296c253 <unknown>
# #13 0x57ad6293c1c7 <unknown>
# #14 0x57ad6293cb3e <unknown>
# #15 0x57ad62bda2cb <unknown>
# #16 0x57ad62bde377 <unknown>
# #17 0x57ad62bc6dfe <unknown>
# #18 0x57ad62bdee42 <unknown>
# #19 0x57ad62bab79f <unknown>
# #20 0x57ad62c03178 <unknown>
# #21 0x57ad62c0334b <unknown>
# #22 0x57ad62c12fbc <unknown>
# #23 0x7a3e7589dac3 <unknown>
#
# ERROR 7757 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.003
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x571efd297e8a <unknown>
# #1 0x571efcf8145c <unknown>
# #2 0x571efcf68816 <unknown>
# #3 0x571efcf683f5 <unknown>
# #4 0x571efcf66336 <unknown>
# #5 0x571efcf669af <unknown>
# #6 0x571efcf77287 <unknown>
# #7 0x571efcf8d55e <unknown>
# #8 0x571efcf92c5b <unknown>
# #9 0x571efcf670fa <unknown>
# #10 0x571efcf8d14f <unknown>
# #11 0x571efd00f195 <unknown>
# #12 0x571efcff0253 <unknown>
# #13 0x571efcfc01c7 <unknown>
# #14 0x571efcfc0b3e <unknown>
# #15 0x571efd25e2cb <unknown>
# #16 0x571efd262377 <unknown>
# #17 0x571efd24adfe <unknown>
# #18 0x571efd262e42 <unknown>
# #19 0x571efd22f79f <unknown>
# #20 0x571efd287178 <unknown>
# #21 0x571efd28734b <unknown>
# #22 0x571efd296fbc <unknown>
# #23 0x7f443444bac3 <unknown>
#
# ERROR 7758 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.003
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5820b5083e8a <unknown>
# #1 0x5820b4d6d45c <unknown>
# #2 0x5820b4d54816 <unknown>
# #3 0x5820b4d543f5 <unknown>
# #4 0x5820b4d52336 <unknown>
# #5 0x5820b4d529af <unknown>
# #6 0x5820b4d63287 <unknown>
# #7 0x5820b4d7955e <unknown>
# #8 0x5820b4d7ec5b <unknown>
# #9 0x5820b4d530fa <unknown>
# #10 0x5820b4d7914f <unknown>
# #11 0x5820b4dfb195 <unknown>
# #12 0x5820b4ddc253 <unknown>
# #13 0x5820b4dac1c7 <unknown>
# #14 0x5820b4dacb3e <unknown>
# #15 0x5820b504a2cb <unknown>
# #16 0x5820b504e377 <unknown>
# #17 0x5820b5036dfe <unknown>
# #18 0x5820b504ee42 <unknown>
# #19 0x5820b501b79f <unknown>
# #20 0x5820b5073178 <unknown>
# #21 0x5820b507334b <unknown>
# #22 0x5820b5082fbc <unknown>
# #23 0x7d4347eafac3 <unknown>
#
# ERROR 7759 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.003
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x568084040e8a <unknown>
# #1 0x568083d2a45c <unknown>
# #2 0x568083d11816 <unknown>
# #3 0x568083d113f5 <unknown>
# #4 0x568083d0f336 <unknown>
# #5 0x568083d0f9af <unknown>
# #6 0x568083d20287 <unknown>
# #7 0x568083d3655e <unknown>
# #8 0x568083d3bc5b <unknown>
# #9 0x568083d100fa <unknown>
# #10 0x568083d362cf <unknown>
# #11 0x568083db8195 <unknown>
# #12 0x568083d99253 <unknown>
# #13 0x568083d691c7 <unknown>
# #14 0x568083d69b3e <unknown>
# #15 0x5680840072cb <unknown>
# #16 0x56808400b377 <unknown>
# #17 0x568083ff3dfe <unknown>
# #18 0x56808400be42 <unknown>
# #19 0x568083fd879f <unknown>
# #20 0x568084030178 <unknown>
# #21 0x56808403034b <unknown>
# #22 0x56808403ffbc <unknown>
# #23 0x7fde7432cac3 <unknown>
#
# ERROR 7760 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.011
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x59ad0aaece8a <unknown>
# #1 0x59ad0a7d645c <unknown>
# #2 0x59ad0a7bd816 <unknown>
# #3 0x59ad0a7bd3f5 <unknown>
# #4 0x59ad0a7bb336 <unknown>
# #5 0x59ad0a7bb9af <unknown>
# #6 0x59ad0a7cc287 <unknown>
# #7 0x59ad0a7e255e <unknown>
# #8 0x59ad0a7e7c5b <unknown>
# #9 0x59ad0a7bc0fa <unknown>
# #10 0x59ad0a7e22cf <unknown>
# #11 0x59ad0a864195 <unknown>
# #12 0x59ad0a845253 <unknown>
# #13 0x59ad0a8151c7 <unknown>
# #14 0x59ad0a815b3e <unknown>
# #15 0x59ad0aab32cb <unknown>
# #16 0x59ad0aab7377 <unknown>
# #17 0x59ad0aa9fdfe <unknown>
# #18 0x59ad0aab7e42 <unknown>
# #19 0x59ad0aa8479f <unknown>
# #20 0x59ad0aadc178 <unknown>
# #21 0x59ad0aadc34b <unknown>
# #22 0x59ad0aaebfbc <unknown>
# #23 0x7971fc565ac3 <unknown>
#
# ERROR 7761 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.004
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x59f780d63e8a <unknown>
# #1 0x59f780a4d45c <unknown>
# #2 0x59f780a34816 <unknown>
# #3 0x59f780a343f5 <unknown>
# #4 0x59f780a32336 <unknown>
# #5 0x59f780a329af <unknown>
# #6 0x59f780a43287 <unknown>
# #7 0x59f780a5955e <unknown>
# #8 0x59f780a5ec5b <unknown>
# #9 0x59f780a330fa <unknown>
# #10 0x59f780a592cf <unknown>
# #11 0x59f780adb195 <unknown>
# #12 0x59f780abc253 <unknown>
# #13 0x59f780a8c1c7 <unknown>
# #14 0x59f780a8cb3e <unknown>
# #15 0x59f780d2a2cb <unknown>
# #16 0x59f780d2e377 <unknown>
# #17 0x59f780d16dfe <unknown>
# #18 0x59f780d2ee42 <unknown>
# #19 0x59f780cfb79f <unknown>
# #20 0x59f780d53178 <unknown>
# #21 0x59f780d5334b <unknown>
# #22 0x59f780d62fbc <unknown>
# #23 0x7d40c2a1eac3 <unknown>
#
# ERROR 7762 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.031
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x
Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x566179559e8a <unknown>
# #1 0x56617924345c <unknown>
# #2 0x56617922a816 <unknown>
# #3 0x56617922a3f5 <unknown>
# #4 0x566179228336 <unknown>
# #5 0x5661792289af <unknown>
# #6 0x566179239287 <unknown>
# #7 0x56617924f55e <unknown>
# #8 0x566179254c5b <unknown>
# #9 0x5661792290fa <unknown>
# #10 0x56617924f2cf <unknown>
# #11 0x5661792d1195 <unknown>
# #12 0x5661792b2253 <unknown>
# #13 0x5661792821c7 <unknown>
# #14 0x566179282b3e <unknown>
# #15 0x5661795202cb <unknown>
# #16 0x566179524377 <unknown>
# #17 0x56617950cdfe <unknown>
# #18 0x566179524e42 <unknown>
# #19 0x5661794f179f <unknown>
# #20 0x566179549178 <unknown>
# #21 0x56617954934b <unknown>
# #22 0x566179558fbc <unknown>
# #23 0x7cc7349bcac3 <unknown>
#
# ERROR 7766 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x555c4a5c9e8a <unknown>
# #1 0x555c4a2b345c <unknown>
# #2 0x555c4a29a816 <unknown>
# #3 0x555c4a29a3f5 <unknown>
# #4 0x555c4a298336 <unknown>
# #5 0x555c4a2989af <unknown>
# #6 0x555c4a2a9287 <unknown>
# #7 0x555c4a2bf55e <unknown>
# #8 0x555c4a2c4c5b <unknown>
# #9 0x555c4a2990fa <unknown>
# #10 0x555c4a2bf2cf <unknown>
# #11 0x555c4a341195 <unknown>
# #12 0x555c4a322253 <unknown>
# #13 0x555c4a2f21c7 <unknown>
# #14 0x555c4a2f2b3e <unknown>
# #15 0x555c4a5902cb <unknown>
# #16 0x555c4a594377 <unknown>
# #17 0x555c4a57cdfe <unknown>
# #18 0x555c4a594e42 <unknown>
# #19 0x555c4a56179f <unknown>
# #20 0x555c4a5b9178 <unknown>
# #21 0x555c4a5b934b <unknown>
# #22 0x555c4a5c8fbc <unknown>
# #23 0x7ec8daa94ac3 <unknown>
#
# ERROR 7767 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.004
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x562c1b1aee8a <unknown>
# #1 0x562c1ae9845c <unknown>
# #2 0x562c1ae7f816 <unknown>
# #3 0x562c1ae7f3f5 <unknown>
# #4 0x562c1ae7d336 <unknown>
# #5 0x562c1ae7d9af <unknown>
# #6 0x562c1ae8e287 <unknown>
# #7 0x562c1aea455e <unknown>
# #8 0x562c1aea9c5b <unknown>
# #9 0x562c1ae7e0fa <unknown>
# #10 0x562c1aea414f <unknown>
# #11 0x562c1af26195 <unknown>
# #12 0x562c1af07253 <unknown>
# #13 0x562c1aed71c7 <unknown>
# #14 0x562c1aed7b3e <unknown>
# #15 0x562c1b1752cb <unknown>
# #16 0x562c1b179377 <unknown>
# #17 0x562c1b161dfe <unknown>
# #18 0x562c1b179e42 <unknown>
# #19 0x562c1b14679f <unknown>
# #20 0x562c1b19e178 <unknown>
# #21 0x562c1b19e34b <unknown>
# #22 0x562c1b1adfbc <unknown>
# #23 0x7cf409145ac3 <unknown>
#
# ERROR 7768 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x56318972ce8a <unknown>
# #1 0x56318941645c <unknown>
# #2 0x5631893fd816 <unknown>
# #3 0x5631893fd3f5 <unknown>
# #4 0x5631893fb336 <unknown>
# #5 0x5631893fb9af <unknown>
# #6 0x56318940c287 <unknown>
# #7 0x56318942255e <unknown>
# #8 0x563189427c5b <unknown>
# #9 0x5631893fc0fa <unknown>
# #10 0x56318942214f <unknown>
# #11 0x5631894a4195 <unknown>
# #12 0x563189485253 <unknown>
# #13 0x5631894551c7 <unknown>
# #14 0x563189455b3e <unknown>
# #15 0x5631896f32cb <unknown>
# #16 0x5631896f7377 <unknown>
# #17 0x5631896dfdfe <unknown>
# #18 0x5631896f7e42 <unknown>
# #19 0x5631896c479f <unknown>
# #20 0x56318971c178 <unknown>
# #21 0x56318971c34b <unknown>
# #22 0x56318972bfbc <unknown>
# #23 0x7c246fb9aac3 <unknown>
#
# ERROR 7769 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.004
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x561cab883e8a <unknown>
# #1 0x561cab56d45c <unknown>
# #2 0x561cab554816 <unknown>
# #3 0x561cab5543f5 <unknown>
# #4 0x561cab552336 <unknown>
# #5 0x561cab5529af <unknown>
# #6 0x561cab563287 <unknown>
# #7 0x561cab57955e <unknown>
# #8 0x561cab57ec5b <unknown>
# #9 0x561cab5530fa <unknown>
# #10 0x561cab57914f <unknown>
# #11 0x561cab5fb195 <unknown>
# #12 0x561cab5dc253 <unknown>
# #13 0x561cab5ac1c7 <unknown>
# #14 0x561cab5acb3e <unknown>
# #15 0x561cab84a2cb <unknown>
# #16 0x561cab84e377 <unknown>
# #17 0x561cab836dfe <unknown>
# #18 0x561cab84ee42 <unknown>
# #19 0x561cab81b79f <unknown>
# #20 0x561cab873178 <unknown>
# #21 0x561cab87334b <unknown>
# #22 0x561cab882fbc <unknown>
# #23 0x78d659f25ac3 <unknown>
#
# ERROR 7770 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.004
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5d0677bcfe8a <unknown>
# #1 0x5d06778b945c <unknown>
# #2 0x5d06778a0816 <unknown>
# #3 0x5d06778a03f5 <unknown>
# #4 0x5d067789e336 <unknown>
# #5 0x5d067789e9af <unknown>
# #6 0x5d06778af287 <unknown>
# #7 0x5d06778c555e <unknown>
# #8 0x5d06778cac5b <unknown>
# #9 0x5d067789f0fa <unknown>
# #10 0x5d06778c52cf <unknown>
# #11 0x5d0677947195 <unknown>
# #12 0x5d0677928253 <unknown>
# #13 0x5d06778f81c7 <unknown>
# #14 0x5d06778f8b3e <unknown>
# #15 0x5d0677b962cb <unknown>
# #16 0x5d0677b9a377 <unknown>
# #17 0x5d0677b82dfe <unknown>
# #18 0x5d0677b9ae42 <unknown>
# #19 0x5d0677b6779f <unknown>
# #20 0x5d0677bbf178 <unknown>
# #21 0x5d0677bbf34b <unknown>
# #22 0x5d0677bcefbc <unknown>
# #23 0x7e792db69ac3 <unknown>
#
# ERROR 7771 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.004
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5c38ac935e8a <unknown>
# #1 0x5c38ac61f45c <unknown>
# #2 0x5c38ac606816 <unknown>
# #3 0x5c38ac6063f5 <unknown>
# #4 0x5c38ac604336 <unknown>
# #5 0x5c38ac6049af <unknown>
# #6 0x5c38ac615287 <unknown>
# #7 0x5c38ac62b55e <unknown>
# #8 0x5c38ac630c5b <unknown>
# #9 0x5c38ac6050fa <unknown>
# #10 0x5c38ac62b2cf <unknown>
# #11 0x5c38ac6ad195 <unknown>
# #12 0x5c38ac68e253 <unknown>
# #13 0x5c38ac65e1c7 <unknown>
# #14 0x57d0db759b3e <unknown>
# #15 0x57d0db9f72cb <unknown>
# #16 0x57d0db9fb377 <unknown>
# #17 0x57d0db9e3dfe <unknown>
# #18 0x57d0db9fbe42 <unknown>
# #19 0x57d0db9c879f <unknown>
# #20 0x57d0dba20178 <unknown>
# #21 0x57d0dba2034b <unknown>
# #22 0x57d0dba2ffbc <unknown>
# #23 0x7b30f5655ac3 <unknown>
#
# ERROR 7775 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x57e7b1762e8a <unknown>
# #1 0x57e7b144c45c <unknown>
# #2 0x57e7b1433816 <unknown>
# #3 0x57e7b14333f5 <unknown>
# #4 0x57e7b1431336 <unknown>
# #5 0x57e7b14319af <unknown>
# #6 0x57e7b1442287 <unknown>
# #7 0x57e7b145855e <unknown>
# #8 0x57e7b145dc5b <unknown>
# #9 0x57e7b14320fa <unknown>
# #10 0x57e7b145814f <unknown>
# #11 0x57e7b14da195 <unknown>
# #12 0x57e7b14bb253 <unknown>
# #13 0x57e7b148b1c7 <unknown>
# #14 0x57e7b148bb3e <unknown>
# #15 0x57e7b17292cb <unknown>
# #16 0x57e7b172d377 <unknown>
# #17 0x57e7b1715dfe <unknown>
# #18 0x57e7b172de42 <unknown>
# #19 0x57e7b16fa79f <unknown>
# #20 0x57e7b1752178 <unknown>
# #21 0x57e7b175234b <unknown>
# #22 0x57e7b1761fbc <unknown>
# #23 0x79caaf039ac3 <unknown>
#
# ERROR 7776 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5af0af517e8a <unknown>
# #1 0x5af0af20145c <unknown>
# #2 0x5af0af1e8816 <unknown>
# #3 0x5af0af1e83f5 <unknown>
# #4 0x5af0af1e6336 <unknown>
# #5 0x5af0af1e69af <unknown>
# #6 0x5af0af1f7287 <unknown>
# #7 0x5af0af20d55e <unknown>
# #8 0x5af0af212c5b <unknown>
# #9 0x5af0af1e70fa <unknown>
# #10 0x5af0af20d14f <unknown>
# #11 0x5af0af28f195 <unknown>
# #12 0x5af0af270253 <unknown>
# #13 0x5af0af2401c7 <unknown>
# #14 0x5af0af240b3e <unknown>
# #15 0x5af0af4de2cb <unknown>
# #16 0x5af0af4e2377 <unknown>
# #17 0x5af0af4cadfe <unknown>
# #18 0x5af0af4e2e42 <unknown>
# #19 0x5af0af4af79f <unknown>
# #20 0x5af0af507178 <unknown>
# #21 0x5af0af50734b <unknown>
# #22 0x5af0af516fbc <unknown>
# #23 0x792ac30daac3 <unknown>
#
# ERROR 7777 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.006
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5988f0dffe8a <unknown>
# #1 0x5988f0ae945c <unknown>
# #2 0x5988f0ad0816 <unknown>
# #3 0x5988f0ad03f5 <unknown>
# #4 0x5988f0ace336 <unknown>
# #5 0x5988f0ace9af <unknown>
# #6 0x5988f0adf287 <unknown>
# #7 0x5988f0af555e <unknown>
# #8 0x5988f0afac5b <unknown>
# #9 0x5988f0acf0fa <unknown>
# #10 0x5988f0af514f <unknown>
# #11 0x5988f0b77195 <unknown>
# #12 0x5988f0b58253 <unknown>
# #13 0x5988f0b281c7 <unknown>
# #14 0x5988f0b28b3e <unknown>
# #15 0x5988f0dc62cb <unknown>
# #16 0x5988f0dca377 <unknown>
# #17 0x5988f0db2dfe <unknown>
# #18 0x5988f0dcae42 <unknown>
# #19 0x5988f0d9779f <unknown>
# #20 0x5988f0def178 <unknown>
# #21 0x5988f0def34b <unknown>
# #22 0x5988f0dfefbc <unknown>
# #23 0x7f40d5594ac3 <unknown>
#
# ERROR 7778 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.005
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x
Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.010
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x55f53090fe8a <unknown>
# #1 0x55f5305f945c <unknown>
# #2 0x55f5305e0816 <unknown>
# #3 0x55f5305e03f5 <unknown>
# #4 0x55f5305de336 <unknown>
# #5 0x55f5305de9af <unknown>
# #6 0x55f5305ef287 <unknown>
# #7 0x55f53060555e <unknown>
# #8 0x55f53060ac5b <unknown>
# #9 0x55f5305df0fa <unknown>
# #10 0x55f53060514f <unknown>
# #11 0x55f530687195 <unknown>
# #12 0x55f530668253 <unknown>
# #13 0x55f5306381c7 <unknown>
# #14 0x55f530638b3e <unknown>
# #15 0x55f5308d62cb <unknown>
# #16 0x55f5308da377 <unknown>
# #17 0x55f5308c2dfe <unknown>
# #18 0x55f5308dae42 <unknown>
# #19 0x55f5308a779f <unknown>
# #20 0x55f5308ff178 <unknown>
# #21 0x55f5308ff34b <unknown>
# #22 0x55f53090efbc <unknown>
# #23 0x7f09e9a70ac3 <unknown>
#
# ERROR 7785 Московская Биржа Message: timeout: Timed out receiving message from renderer: -0.006
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5af3670a5e8a <unknown>
# #1 0x5af366d8f45c <unknown>
# #2 0x5af366d76816 <unknown>
# #3 0x5af366d763f5 <unknown>
# #4 0x5af366d74336 <unknown>
# #5 0x5af366d749af <unknown>
# #6 0x5af366d85287 <unknown>
# #7 0x5af366d9b55e <unknown>
# #8 0x5af366da0c5b <unknown>
# #9 0x5af366d750fa <unknown>
# #10 0x5af366d9b2cf <unknown>
# #11 0x5af366e1d195 <unknown>
# #12 0x5af366dfe253 <unknown>
# #13 0x5af366dce1c7 <unknown>
# #14 0x5af366dceb3e <unknown>
# #15 0x5af36706c2cb <unknown>
# ...
# DONE 9077 Транспортная группа FESCO
# DONE 9078 Транспортная группа FESCO
# DONE 9079 Транспортная группа FESCO
# DONE 9080 Транспортная группа FESCO
# DONE 9081 Транспортная группа FESCO
# DONE 9082 Транспортная группа FESCO
# DONE 9083 Транспортная группа FESCO
# DONE 9084 Транспортная группа FESCO
# DONE 9085 Транспортная группа FESCO
# DONE 9086 Транспортная группа FESCO
# DONE 9087 Транспортная группа FESCO
# DONE 9088 Транспортная группа FESCO
# DONE 9089 Транспортная группа FESCO
# DONE 9090 Транспортная группа FESCO
# DONE 9091 Транспортная группа FESCO
# DONE 9092 Транспортная группа FESCO
# DONE 9093 Транспортная группа FESCO
# DONE 9094 Транспортная группа FESCO
# DONE 9095 Транспортная группа FESCO
# DONE 9096 Транспортная группа FESCO
# DONE 9097 Транспортная группа FESCO
# DONE 9098 Транспортная группа FESCO
# DONE 9099 Транспортная группа FESCO
# DONE 9100 Транспортная группа FESCO
# DONE 9101 Транспортная группа FESCO
# DONE 9102 Транспортная группа FESCO
# DONE 9103 Транспортная группа FESCO
# DONE 9104 Транспортная группа FESCO
# DONE 9105 Транспортная группа FESCO
# DONE 9106 Транспортная группа FESCO
# DONE 9107 Транспортная группа FESCO
# DONE 9108 Транспортная группа FESCO
# DONE 9109 Транспортная группа FESCO
# DONE 9110 Транспортная группа FESCO
# DONE 9111 Транспортная группа FESCO
# DONE 9112 Транспортная группа FESCO
# DONE 9113 Транспортная группа FESCO
# DONE 9114 Транспортная группа FESCO
# DONE 9115 Транспортная группа FESCO
# DONE 9116 Транспортная группа FESCO
# DONE 9117 Транспортная группа FESCO
# DONE 9118 Транспортная группа FESCO
# DONE 9119 Транспортная группа FESCO
# DONE 9120 Транспортная группа FESCO
# DONE 9121 Транспортная группа FESCO
# DONE 9122 Транспортная группа FESCO
# DONE 9123 Транспортная группа FESCO
# DONE 9124 Транспортная группа FESCO
# DONE 9125 Транспортная группа FESCO
# DONE 9126 Транспортная группа FESCO
# DONE 9127 Транспортная группа FESCO
# DONE 9128 Транспортная группа FESCO
# DONE 9129 Транспортная группа FESCO
# DONE 9130 Транспортная группа FESCO
# DONE 9131 Транспортная группа FESCO
# DONE 9132 Транспортная группа FESCO
# DONE 9133 Транспортная группа FESCO
# DONE 9134 Транспортная группа FESCO
# DONE 9135 Транспортная группа FESCO
# DONE 9136 Транспортная группа FESCO
# DONE 9137 Транспортная группа FESCO
# DONE 9138 Транспортная группа FESCO
# DONE 9139 Транспортная группа FESCO
# DONE 9140 Транспортная группа FESCO
# DONE 9141 Транспортная группа FESCO
# DONE 9142 Транспортная группа FESCO
# DONE 9143 Транспортная группа FESCO
# DONE 9144 Транспортная группа FESCO
# DONE 9145 Транспортная группа FESCO
# DONE 9146 Транспортная группа FESCO
# DONE 9147 Транспортная группа FESCO
# DONE 9148 Транспортная группа FESCO
# DONE 9149 Транспортная группа FESCO
# DONE 9150 Транспортная группа FESCO
# DONE 9151 Транспортная группа FESCO
# DONE 9152 Транспортная группа FESCO
# DONE 9153 Транспортная группа FESCO
# DONE 9154 Транспортная группа FESCO
# DONE 9155 Транспортная группа FESCO
# DONE 9156 Транспортная группа FESCO
# DONE 9157 Транспортная группа FESCO
# DONE 9158 Транспортная группа FESCO
# DONE 9159 Транспортная группа FESCO
# DONE 9160 Транспортная группа FESCO
# DONE 9161 Транспортная группа FESCO
# DONE 9162 Транспортная группа FESCO
# DONE 9163 Транспортная группа FESCO
# DONE 9164 Транспортная группа FESCO
# DONE 9165 Транспортная группа FESCO
# DONE 9166 Транспортная группа FESCO
# DONE 9167 Транспортная группа FESCO
# DONE 9168 Транспортная группа FESCO
# DONE 9169 Транспортная группа FESCO
# DONE 9170 Транспортная группа FESCO
# DONE 9171 Транспортная группа FESCO
# DONE 9172 Транспортная группа FESCO
# DONE 9173 Транспортная группа FESCO
# DONE 9174 Транспортная группа FESCO
# DONE 9175 Транспортная группа FESCO
# DONE 9176 Транспортная группа FESCO
# DONE 9177 Транспортная группа FESCO
# DONE 9178 Транспортная группа FESCO
# DONE 9179 Транспортная группа FESCO
# DONE 9180 Транспортная группа FESCO
# DONE 9181 Транспортная группа FESCO
# DONE 9182 Транспортная группа FESCO
# DONE 9183 Транспортная группа FESCO
# DONE 9184 Транспортная группа FESCO
# DONE 9185 Транспортная группа FESCO
# DONE 9186 Транспортная группа FESCO
# DONE 9187 Транспортная группа FESCO
# DONE 9188 Транспортная группа FESCO
# DONE 9189 Транспортная группа FESCO
# DONE 9190 Транспортная группа FESCO
# DONE 9191 Транспортная группа FESCO
# DONE 9192 Транспортная группа FESCO
# DONE 9193 Транспортная группа FESCO
# DONE 9194 Транспортная группа FESCO
# DONE 9195 Транспортная группа FESCO
# DONE 9196 Транспортная группа FESCO
# DONE 9197 Транспортная группа FESCO
# DONE 9198 Транспортная группа FESCO
# DONE 9199 Транспортная группа FESCO
# DONE 9200 Транспортная группа FESCO
# DONE 9201 Транспортная группа FESCO
# DONE 9202 Транспортная группа FESCO
# DONE 9203 Транспортная группа FESCO
# DONE 9204 Транспортная группа FESCO
# DONE 9205 Транспортная группа FESCO
# DONE 9206 Транспортная группа FESCO
# DONE 9207 Транспортная группа FESCO
# DONE 9208 Транспортная группа FESCO
# DONE 9209 Транспортная группа FESCO
# DONE 9210 Транспортная группа FESCO
# DONE 9211 Транспортная группа FESCO
# DONE 9212 Транспортная группа FESCO
# DONE 9213 Транспортная группа FESCO
# DONE 9214 Транспортная группа FESCO
# DONE 9215 Транспортная группа FESCO
# DONE 9216 Транспортная группа FESCO
# DONE 9217 Транспортная группа FESCO
# DONE 9218 Транспортная группа FESCO
# DONE 9219 Транспортная группа FESCO
# DONE 9220 Транспортная группа FESCO
# DONE 9221 Транспортная группа FESCO
# DONE 9222 Транспортная группа FESCO
# DONE 9223 Транспортная группа FESCO
# DONE 9224 Транспортная группа FESCO
# DONE 9225 Транспортная группа FESCO
# DONE 9226 Транспортная группа FESCO
# DONE 9227 Транспортная группа FESCO
# DONE 9228 Транспортная группа FESCO
# DONE 9229 Транспортная группа FESCO
# DONE 9230 Транспортная группа FESCO
# DONE 9231 Транспортная группа FESCO
# DONE 9232 Транспортная группа FESCO
# DONE 9233 Транспортная группа FESCO
# DONE 9234 Транспортная группа FESCO
# DONE 9235 Транспортная группа FESCO
# DONE 9236 Транспортная группа FESCO
# DONE 9237 Транспортная группа FESCO
# DONE 9238 Транспортная группа FESCO
# DONE 9239 Транспортная группа FESCO
# DONE 9240 Транспортная группа FESCO
# DONE 9241 Транспортная группа FESCO
# DONE 9242 Транспортная группа FESCO
# DONE 9243 Транспортная группа FESCO
# DONE 9244 Транспортная группа FESCO
# DONE 9245 Транспортная группа FESCO
# DONE 9246 Транспортная группа FESCO
# DONE 9247 Транспортная группа FESCO
# DONE 9248 Транспортная группа FESCO
# DONE 9249 Транспортная группа FESCO
# DONE 9250 Транспортная группа FESCO
# DONE 9251 Транспортная группа FESCO
# DONE 9252 Южуралзолото Группа Компаний
# DONE 9253 Транспортная группа FESCO
# DONE 9254 Транспортная группа FESCO
# DONE 9255 Транспортная группа FESCO
# DONE 9256 Южуралзолото Группа Компаний
# DONE 9257 Южуралзолото Группа Компаний
# DONE 9258 Южуралзолото Группа Компаний
# DONE 9259 Южуралзолото Группа Компаний
# DONE 9260 Южуралзолото Группа Компаний
# DONE 9261 Южуралзолото Группа Компаний
# DONE 9262 Южуралзолото Группа Компаний
# DONE 9263 Южуралзолото Группа Компаний
# DONE 9264 Южуралзолото Группа Компаний
# DONE 9265 Южуралзолото Группа Компаний
# DONE 9266 Южуралзолото Группа Компаний
# DONE 9267 Южуралзолото Группа Компаний
# DONE 9268 Южуралзолото Группа Компаний
# DONE 9269 Южуралзолото Группа Компаний
# DONE 9270 Южуралзолото Группа Компаний
# DONE 9271 Южуралзолото Группа Компаний
# DONE 9272 Южуралзолото Группа Компаний
# DONE 9273 Южуралзолото Группа Компаний
# DONE 9274 Южуралзолото Группа Компаний
# DONE 9275 Южуралзолото Группа Компаний
# DONE 9276 Южуралзолото Группа Компаний
# DONE 9277 Южуралзолото Группа Компаний
# DONE 9278 Южуралзолото Группа Компаний
# DONE 9279 Южуралзолото Группа Компаний
# DONE 9280 Южуралзолото Группа Компаний
# DONE 9281 Южуралзолото Группа Компаний
# DONE 9282 Транспортная группа FESCO
# DONE 9283 Транспортная группа FESCO
# DONE 9284 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9285 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9286 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9287 Транспортная группа FESCO
# DONE 9288 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9289 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9290 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9291 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9292 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9293 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9294 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9295 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9296 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9297 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9298 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9299 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9300 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9301 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9302 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9303 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9304 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9305 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9306 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9307 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9308 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9309 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9310 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9311 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9312 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9313 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9314 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9315 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9316 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9317 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9318 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9319 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9320 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9321 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9322 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9323 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9324 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9325 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9326 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9327 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9328 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9329 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9330 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9331 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9332 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9333 Якутская топливно-энергетическая компания (ЯТЭК)
# ERROR 9334 Юникредит Банк Message: timeout: Timed out receiving message from renderer: -0.006
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x5a597e50fe8a <unknown>
# #1 0x5a597e1f945c <unknown>
# #2 0x5a597e1e0816 <unknown>
# #3 0x5a597e1e03f5 <unknown>
# #4 0x5a597e1de336 <unknown>
# #5 0x5a597e1de9af <unknown>
# #6 0x5a597e1ef287 <unknown>
# #7 0x5a597e20555e <unknown>
# #8 0x5a597e20ac5b <unknown>
# #9 0x5a597e1df0fa <unknown>
# #10 0x5a597e20514f <unknown>
# #11 0x5a597e287195 <unknown>
# #12 0x5a597e268253 <unknown>
# #13 0x5a597e2381c7 <unknown>
# #14 0x5a597e238b3e <unknown>
# #15 0x5a597e4d62cb <unknown>
# #16 0x5a597e4da377 <unknown>
# #17 0x5a597e4c2dfe <unknown>
# #18 0x5a597e4dae42 <unknown>
# #19 0x5a597e4a779f <unknown>
# #20 0x5a597e4ff178 <unknown>
# #21 0x5a597e4ff34b <unknown>
# #22 0x5a597e50efbc <unknown>
# #23 0x7cdc4d508ac3 <unknown>
#
# ERROR 9335 Юникредит Банк Message: timeout: Timed out receiving message from renderer: -0.007
#   (Session info: chrome-headless-shell=125.0.6422.78)
# Stacktrace:
# #0 0x572d9e516e8a <unknown>
# #1 0x572d9e20045c <unknown>
# #2 0x572d9e1e7816 <unknown>
# #3 0x572d9e1e73f5 <unknown>
# #4 0x572d9e1e5336 <unknown>
# #5 0x572d9e1e59af <unknown>
# #6 0x572d9e1f6287 <unknown>
# #7 0x572d9e20c55e <unknown>
# #8 0x572d9e211c5b <unknown>
# #9 0x572d9e1e60fa <unknown>
# #10 0x572d9e20c14f <unknown>
# #11 0x572d9e28e195 <unknown>
# #12 0x572d9e26f253 <unknown>
# #13 0x572d9e23f1c7 <unknown>
# #14 0x572d9e23fb3e <unknown>
# #15 0x572d9e4dd2cb <unknown>
# #16 0x572d9e4e1377 <unknown>
# #17 0x572d9e4c9dfe <unknown>
# #18 0x572d9e4e1e42 <unknown>
# #19 0x572d9e4ae79f <unknown>
# #20 0x572d9e506178 <unknown>
# #21 0x572d9e50634b <unknown>
# #22 0x572d9e515fbc <unknown>
# #23 0x7a7379171ac3 <unknown>
#
# DONE 9336 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9337 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9338 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9339 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9340 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9341 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9342 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9343 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9344 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9345 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9346 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9347 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9348 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9349 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9350 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9351 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9352 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9353 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9354 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9355 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9356 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9357 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9358 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9359 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9360 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9361 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9362 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9363 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9364 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9365 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9366 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9367 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9368 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9369 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9370 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9371 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9372 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9373 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9374 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9375 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9376 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9377 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9378 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9379 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9380 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9381 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9382 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9383 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9384 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9385 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9386 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9387 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9388 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9389 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9390 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9391 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9392 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9393 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9394 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9395 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9396 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9397 Якутская топливно-энергетическая компания (ЯТЭК)
# DONE 9398 Якутская топливно-энергетическая компания (ЯТЭК)
# Parcing is finished!
# CPU times: user 4h 48min 34s, sys: 12min 57s, total: 5h 1min 32s
# Wall time: 6h 47min 52s

# %%
len(parsed_data.company.unique())
# Out:
# 130

# %%
parsed_data
# Out:
#                                                   company  \
# 0                                "Каустик" (г. Волгоград)
# 1                                "Каустик" (г. Волгоград)
# 2                                "Каустик" (г. Волгоград)
# 3                                "Каустик" (г. Волгоград)
# 4                                "Каустик" (г. Волгоград)
# ...                                                   ...
# 1197237  Якутская топливно-энергетическая компания (ЯТЭК)
# 1197238  Якутская топливно-энергетическая компания (ЯТЭК)
# 1197239  Якутская топливно-энергетическая компания (ЯТЭК)
# 1197240  Якутская топливно-энергетическая компания (ЯТЭК)
# 1197241  Якутская топливно-энергетическая компания (ЯТЭК)
#
#                                                        url  \
# 0        https://www.kaustik.ru/ru/index.php/partneram/...
# 1        https://www.kaustik.ru/ru/index.php/partneram/...
# 2        https://www.kaustik.ru/ru/index.php/partneram/...
# 3        https://www.kaustik.ru/ru/index.php/partneram/...
# 4        https://www.kaustik.ru/ru/index.php/partneram/...
# ...                                                    ...
# 1197237     https://www.yatec.ru/press-centr/photogallery/
# 1197238     https://www.yatec.ru/press-centr/photogallery/
# 1197239     https://www.yatec.ru/press-centr/photogallery/
# 1197240     https://www.yatec.ru/press-centr/photogallery/
# 1197241     https://www.yatec.ru/press-centr/photogallery/
#
#                                                       text
# 0        обращать внимание мошеннический схема ао кауст...
# 1                                   ао каустик г волгоград
# 2                        служба поддержка клиент тело факс
# 3        email sbyturkaustikru контакт управление реали...
# 4                                                  главный
# ...                                                    ...
# 1197237                                правовой информация
# 1197238                       положение конфиденциальность
# 1197239                     политика использование cookies
# 1197240                                     сделать студия
# 1197241                                          art gorka
#
# [1197242 rows x 3 columns]
